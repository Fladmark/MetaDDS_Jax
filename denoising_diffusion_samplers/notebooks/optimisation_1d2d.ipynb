# %%
from dds.configs.config import set_task, get_config
from dds.train_dds import train_dds

import numpy as onp
funnel_config = get_config()

# Time and step settings (Need to be done before calling set_task)
funnel_config.model.tfinal = 6.4
funnel_config.model.dt = 0.05 #0.05

if funnel_config.model.reference_process_key == "oudstl":
    funnel_config.model.step_scheme_key = "cos_sq"

from dds.targets.toy_targets import get_attr
### SET TASK
task = "levy"
div = 1
c = 100000

# div, e, other_dim = get_attr()
# div = str(div).replace(".", "")
# e = str(e).replace(".", "")
#
# save_name = f"{task}_s{div}_plus{e}_od{other_dim}"


funnel_config = set_task(funnel_config, task, div, c)
funnel_config.model.reference_process_key = "oudstl"
funnel_config.model.reference_process_key = "pisstl"
funnel_config.model.step_scheme_key = "uniform"
funnel_config.model.step_scheme_key = "cos_sq"
# funnel_config.model.reference_process_key = "pisstl"
# funnel_config.model.step_scheme_key = "uniform"

# exp_dec
# cos_sq
# uniform
# last_small
# linear_dds
# linear
# uniform_dds

if funnel_config.model.reference_process_key == "oudstl":
    funnel_config.model.step_scheme_key = "cos_sq"
    
    # Opt setting for funnel
    funnel_config.model.sigma = 1.075
    funnel_config.model.alpha = 0.6875
    funnel_config.model.m = 1.0
        
    # Path opt settings    
    funnel_config.model.exp_dds = False


funnel_config.model.stl = False
funnel_config.model.detach_stl_drift = False

# funnel_config.model.stl = True
# funnel_config.model.detach_stl_drift = True

funnel_config.trainer.notebook = True
funnel_config.trainer.epochs = 50
# Opt settings we use
# funnel_config.trainer.learning_rate = 0.0001
funnel_config.trainer.learning_rate = 1 * 10**(-3)
funnel_config.trainer.lr_sch_base_dec = 0.90 # For funnel

# %%
l = []
for c in [1, 10, 100, 1000, 10000]:
    funnel_config.trainer.epochs = 50
    funnel_config = set_task(funnel_config, task, div, c)
    out_dict = train_dds(funnel_config)
    l.append(out_dict)
# Out:
# Best training loss: 0.011783059686422348
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -2.4606261253356934)
# Best training loss: 0.008362729102373123
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -2.457303762435913)
# Best training loss: 0.005088452249765396
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -2.452901601791382)
# Best training loss: 0.002478755544871092
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -2.447727680206299)
# Best training loss: 0.0016971257282420993
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -2.481067419052124)
# Best training loss: 0.004782459232956171
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -2.527752161026001)
# Best training loss: 0.0038413279689848423
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -2.5428085327148438)
# Best training loss: 0.0010714181698858738
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -2.563133955001831)
# Best training loss: 0.0009518689475953579
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -2.624781847000122)
# Best training loss: 0.0003384836600162089
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -2.6493382453918457)
# Best training loss: 4.810025347978808e-05
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -2.7280125617980957)
# Best training loss: 0.00027611322002485394
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -2.712155342102051)
# Best training loss: 0.00027410921757109463
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -2.6771435737609863)
# Best training loss: 2.866076465579681e-05
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -2.73952054977417)
# Best training loss: 0.000560365617275238
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -2.853745698928833)
# Best training loss: 9.327873704023659e-05
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -2.8274450302124023)
# Best training loss: 0.0001728117058519274
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -2.812894105911255)
# Best training loss: 0.00027882130234502256
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -2.7606494426727295)
# Best training loss: 0.0011360283242538571
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -2.9258081912994385)
# Best training loss: 0.0015398822724819183
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -2.9072177410125732)
# Best training loss: 7.633132190676406e-05
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -2.974494218826294)
# Best training loss: 0.00046782338176853955
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -3.0261032581329346)
# Best training loss: 0.00016900530317798257
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -3.127995252609253)
# Best training loss: 0.0011065606959164143
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -3.112673044204712)
# Best training loss: 1.5077463103807531e-05
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -3.088020086288452)
# Best training loss: 2.0867886632913724e-05
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -3.1326467990875244)
# Best training loss: 0.0005621925229206681
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -3.128000259399414)
# Best training loss: 0.0007184197893366218
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -3.247354030609131)
# Best training loss: 0.004241867456585169
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -3.2445831298828125)
# Best training loss: 0.000624398177023977
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -3.234445571899414)
# Best training loss: 0.001106373150832951
# ('epoch: %s %s  loss: %s', 30, 'TRAIN', -3.293487071990967)
# Best training loss: 0.0027537152636796236
# ('epoch: %s %s  loss: %s', 31, 'TRAIN', -3.380448818206787)
# Best training loss: 0.0034807969350367785
# ('epoch: %s %s  loss: %s', 32, 'TRAIN', -3.394580125808716)
# Best training loss: 0.000652517715934664
# ('epoch: %s %s  loss: %s', 33, 'TRAIN', -3.476478338241577)
# Best training loss: 0.00279984506778419
# ('epoch: %s %s  loss: %s', 34, 'TRAIN', -3.4847798347473145)
# Best training loss: 7.953072054078802e-05
# ('epoch: %s %s  loss: %s', 35, 'TRAIN', -3.391512155532837)
# Best training loss: 0.011783527210354805
# ('epoch: %s %s  loss: %s', 36, 'TRAIN', -3.692812442779541)
# Best training loss: 0.0010007467353716493
# ('epoch: %s %s  loss: %s', 37, 'TRAIN', -3.4229204654693604)
# Best training loss: 0.0048119621351361275
# ('epoch: %s %s  loss: %s', 38, 'TRAIN', -3.538846731185913)
# Best training loss: 0.005265301559120417
# ('epoch: %s %s  loss: %s', 39, 'TRAIN', -3.5993590354919434)
# Best training loss: 0.0037405602633953094
# ('epoch: %s %s  loss: %s', 40, 'TRAIN', -3.6594390869140625)
# Best training loss: 0.0025188052095472813
# ('epoch: %s %s  loss: %s', 41, 'TRAIN', -3.787233591079712)
# Best training loss: 0.00200220150873065
# ('epoch: %s %s  loss: %s', 42, 'TRAIN', -3.746009349822998)
# Best training loss: 0.0007375534623861313
# ('epoch: %s %s  loss: %s', 43, 'TRAIN', -3.6745946407318115)
# Best training loss: 0.0001623880089027807
# ('epoch: %s %s  loss: %s', 44, 'TRAIN', -3.6692984104156494)
# Best training loss: 0.003189264563843608
# ('epoch: %s %s  loss: %s', 45, 'TRAIN', -3.769059658050537)
# Best training loss: 0.0005753007717430592
# ('epoch: %s %s  loss: %s', 46, 'TRAIN', -3.7903523445129395)
# Best training loss: 0.0013162401737645268
# ('epoch: %s %s  loss: %s', 47, 'TRAIN', -3.776627540588379)
# Best training loss: 0.0023964201100170612
# ('epoch: %s %s  loss: %s', 48, 'TRAIN', -3.6468284130096436)
# Best training loss: 0.009837175719439983
# ('epoch: %s %s  loss: %s', 49, 'TRAIN', -3.955721616744995)
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -3.821789264678955)
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -3.917844533920288)
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -3.8869528770446777)
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -3.90622878074646)
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -3.7740461826324463)
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -3.7502076625823975)
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -3.789383888244629)
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -3.790100336074829)
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -3.78466796875)
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -3.9222800731658936)
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -3.83453631401062)
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -3.8073151111602783)
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -3.7746379375457764)
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -3.8400332927703857)
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -3.8940768241882324)
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -3.7431535720825195)
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -3.8436105251312256)
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -3.744483709335327)
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -3.7609455585479736)
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -3.801370859146118)
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -3.908438205718994)
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -3.6599678993225098)
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -3.8111677169799805)
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -3.8320059776306152)
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -3.74420428276062)
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -3.8178765773773193)
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -3.8712685108184814)
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -3.8103156089782715)
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -3.816679000854492)
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -3.7936363220214844)
# Best training loss: 0.00782895740121603
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -6.975766181945801)
# Best training loss: 0.005621763877570629
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -7.269346237182617)
# Best training loss: 0.0018948247889056802
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -7.70257568359375)
# Best training loss: 0.0005558850825764239
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -8.037647247314453)
# Best training loss: 0.00114988605491817
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -8.53470230102539)
# Best training loss: 0.00016845008940435946
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -8.957715034484863)
# Best training loss: 0.00032053078757598996
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -9.172890663146973)
# Best training loss: 0.00014130568888504058
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -9.174592018127441)
# Best training loss: 0.00044278628774918616
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -8.952220916748047)
# Best training loss: 3.4319698897888884e-05
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -8.893486976623535)
# Best training loss: 0.00010464679508004338
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -8.933138847351074)
# Best training loss: 8.07737887953408e-05
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -9.092758178710938)
# Best training loss: 0.00014553854998666793
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -9.24031925201416)
# Best training loss: 6.994636123636155e-07
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -9.351140975952148)
# Best training loss: 4.324788460507989e-05
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -9.50327205657959)
# Best training loss: 0.00015830011398065835
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -9.449688911437988)
# Best training loss: 9.008923370856792e-05
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -9.447410583496094)
# Best training loss: 3.0071916626184247e-05
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -9.321244239807129)
# Best training loss: 1.1344117410772014e-05
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -9.386834144592285)
# Best training loss: 1.2623493603314273e-05
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -9.321512222290039)
# Best training loss: 3.8720318116247654e-05
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -9.3617582321167)
# Best training loss: 0.00014538472169078887
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -9.406671524047852)
# Best training loss: 0.0002464077842887491
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -9.492813110351562)
# Best training loss: 5.497313031810336e-05
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -9.502767562866211)
# Best training loss: 0.00011020042438758537
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -9.600702285766602)
# Best training loss: 0.00012299721129238605
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -9.483930587768555)
# Best training loss: 0.000334242737153545
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -9.46670913696289)
# Best training loss: 0.00026654297835193574
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -9.495049476623535)
# Best training loss: 0.0001469844428356737
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -9.46210765838623)
# Best training loss: 0.0004018619074486196
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -9.471014976501465)
# Best training loss: 0.0003800018166657537
# ('epoch: %s %s  loss: %s', 30, 'TRAIN', -9.528596878051758)
# Best training loss: 0.000155445042764768
# ('epoch: %s %s  loss: %s', 31, 'TRAIN', -9.547715187072754)
# Best training loss: 0.0003799194237217307
# ('epoch: %s %s  loss: %s', 32, 'TRAIN', -9.506811141967773)
# Best training loss: 0.0004334193654358387
# ('epoch: %s %s  loss: %s', 33, 'TRAIN', -9.545230865478516)
# Best training loss: 0.0004357562283985317
# ('epoch: %s %s  loss: %s', 34, 'TRAIN', -9.426039695739746)
# Best training loss: 0.0005033113993704319
# ('epoch: %s %s  loss: %s', 35, 'TRAIN', -9.467252731323242)
# Best training loss: 0.00017717492301017046
# ('epoch: %s %s  loss: %s', 36, 'TRAIN', -9.555882453918457)
# Best training loss: 9.644091915106401e-05
# ('epoch: %s %s  loss: %s', 37, 'TRAIN', -9.53519344329834)
# Best training loss: 0.0005915309302508831
# ('epoch: %s %s  loss: %s', 38, 'TRAIN', -9.44434642791748)
# Best training loss: 0.0003719687520060688
# ('epoch: %s %s  loss: %s', 39, 'TRAIN', -9.573147773742676)
# Best training loss: 9.311331268690992e-06
# ('epoch: %s %s  loss: %s', 40, 'TRAIN', -9.523490905761719)
# Best training loss: 0.0002746305544860661
# ('epoch: %s %s  loss: %s', 41, 'TRAIN', -9.564215660095215)
# Best training loss: 0.00024480876163579524
# ('epoch: %s %s  loss: %s', 42, 'TRAIN', -9.554071426391602)
# Best training loss: 0.0002029769093496725
# ('epoch: %s %s  loss: %s', 43, 'TRAIN', -9.588090896606445)
# Best training loss: 0.00017299554019700736
# ('epoch: %s %s  loss: %s', 44, 'TRAIN', -9.5616455078125)
# Best training loss: 7.991002348717302e-05
# ('epoch: %s %s  loss: %s', 45, 'TRAIN', -9.567631721496582)
# Best training loss: 4.312305463827215e-06
# ('epoch: %s %s  loss: %s', 46, 'TRAIN', -9.48986530303955)
# Best training loss: 1.7048947483999655e-05
# ('epoch: %s %s  loss: %s', 47, 'TRAIN', -9.610909461975098)
# Best training loss: 0.00012690412404481322
# ('epoch: %s %s  loss: %s', 48, 'TRAIN', -9.599769592285156)
# Best training loss: 0.000253411999437958
# ('epoch: %s %s  loss: %s', 49, 'TRAIN', -9.522721290588379)
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -9.576617240905762)
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -9.520283699035645)
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -9.530316352844238)
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -9.573143005371094)
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -9.553009986877441)
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -9.482283592224121)
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -9.579115867614746)
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -9.583027839660645)
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -9.549383163452148)
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -9.56946086883545)
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -9.547463417053223)
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -9.569046974182129)
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -9.602777481079102)
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -9.572729110717773)
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -9.57136344909668)
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -9.633855819702148)
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -9.582459449768066)
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -9.507756233215332)
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -9.547182083129883)
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -9.50139331817627)
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -9.44410228729248)
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -9.511384010314941)
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -9.48812198638916)
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -9.603936195373535)
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -9.49409294128418)
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -9.395893096923828)
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -9.586453437805176)
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -9.642849922180176)
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -9.595199584960938)
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -9.519514083862305)
# Best training loss: 0.0013318659039214253
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -68.7648696899414)
# Best training loss: 0.0003019886207766831
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -85.15284729003906)
# Best training loss: 2.6268110104865627e-06
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -91.23885345458984)
# Best training loss: 3.316187212476507e-05
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -91.5392837524414)
# Best training loss: 8.375098695978522e-05
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -89.68522644042969)
# Best training loss: 2.377209602855146e-05
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -88.59420776367188)
# Best training loss: 3.7282406992744654e-06
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -88.39330291748047)
# Best training loss: 6.219500846782466e-06
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -88.85037994384766)
# Best training loss: 7.858456228859723e-06
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -89.67630004882812)
# Best training loss: 1.8700658984016627e-05
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -90.64567565917969)
# Best training loss: 3.8177451642695814e-05
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -91.70549774169922)
# Best training loss: 3.2071853638626635e-05
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -92.55474090576172)
# Best training loss: 3.309032535980805e-06
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -93.35963439941406)
# Best training loss: 1.0155018571822438e-05
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -93.60922241210938)
# Best training loss: 1.768807487678714e-05
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -93.80133819580078)
# Best training loss: 2.969769229821395e-05
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -93.23835754394531)
# Best training loss: 5.934484215686098e-05
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -92.84589385986328)
# Best training loss: 7.273950814123964e-06
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -92.14678192138672)
# Best training loss: 3.278556323493831e-05
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -92.26072692871094)
# Best training loss: 3.934730193577707e-05
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -92.76736450195312)
# Best training loss: 1.957530366780702e-05
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -93.14723205566406)
# Best training loss: 8.479324606014416e-06
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -93.54827117919922)
# Best training loss: 3.2784566883492516e-06
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -94.09519958496094)
# Best training loss: 1.0676475312720868e-06
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -94.51184844970703)
# Best training loss: 1.8114486977083288e-07
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -94.61027526855469)
# Best training loss: 1.3806393326376565e-06
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -94.53372192382812)
# Best training loss: 6.048726390872616e-06
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -94.54558563232422)
# Best training loss: 1.5806455849087797e-05
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -94.48590850830078)
# Best training loss: 2.8341215511318296e-05
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -94.55159759521484)
# Best training loss: 2.8077636670786887e-05
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -94.65189361572266)
# Best training loss: 1.990880946323159e-06
# ('epoch: %s %s  loss: %s', 30, 'TRAIN', -94.774169921875)
# Best training loss: 1.755796438374091e-05
# ('epoch: %s %s  loss: %s', 31, 'TRAIN', -94.85211181640625)
# Best training loss: 2.171259984606877e-05
# ('epoch: %s %s  loss: %s', 32, 'TRAIN', -94.4854736328125)
# Best training loss: 8.65251786308363e-06
# ('epoch: %s %s  loss: %s', 33, 'TRAIN', -94.62469482421875)
# Best training loss: 1.7045931599568576e-05
# ('epoch: %s %s  loss: %s', 34, 'TRAIN', -93.79985809326172)
# Best training loss: 2.7081870939582586e-05
# ('epoch: %s %s  loss: %s', 35, 'TRAIN', -93.64836120605469)
# Best training loss: 2.277675775985699e-05
# ('epoch: %s %s  loss: %s', 36, 'TRAIN', -94.21003723144531)
# Best training loss: 1.899164817587007e-05
# ('epoch: %s %s  loss: %s', 37, 'TRAIN', -94.62548828125)
# Best training loss: 8.517557034792844e-06
# ('epoch: %s %s  loss: %s', 38, 'TRAIN', -94.35130310058594)
# Best training loss: 1.2959404557477683e-05
# ('epoch: %s %s  loss: %s', 39, 'TRAIN', -95.22906494140625)
# Best training loss: 3.3752563467714936e-05
# ('epoch: %s %s  loss: %s', 40, 'TRAIN', -94.89009857177734)
# Best training loss: 2.9694117984035984e-05
# ('epoch: %s %s  loss: %s', 41, 'TRAIN', -95.26481628417969)
# Best training loss: 9.669748578744475e-06
# ('epoch: %s %s  loss: %s', 42, 'TRAIN', -95.29853820800781)
# Best training loss: 5.380805419008539e-07
# ('epoch: %s %s  loss: %s', 43, 'TRAIN', -95.45323944091797)
# Best training loss: 1.2658625792028033e-06
# ('epoch: %s %s  loss: %s', 44, 'TRAIN', -95.4220199584961)
# Best training loss: 7.280268164322479e-06
# ('epoch: %s %s  loss: %s', 45, 'TRAIN', -95.51939392089844)
# Best training loss: 1.1585577340156306e-05
# ('epoch: %s %s  loss: %s', 46, 'TRAIN', -95.05835723876953)
# Best training loss: 1.152425647887867e-05
# ('epoch: %s %s  loss: %s', 47, 'TRAIN', -95.74678039550781)
# Best training loss: 4.808752692042617e-06
# ('epoch: %s %s  loss: %s', 48, 'TRAIN', -95.5201416015625)
# Best training loss: 3.2728524956837646e-07
# ('epoch: %s %s  loss: %s', 49, 'TRAIN', -95.12259674072266)
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -95.31250762939453)
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -95.13617706298828)
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -95.23640441894531)
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -95.31538391113281)
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -95.28327941894531)
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -95.10310363769531)
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -95.23013305664062)
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -95.52536010742188)
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -95.29335021972656)
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -95.22461700439453)
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -95.17742919921875)
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -95.44066619873047)
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -95.52877044677734)
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -95.41177368164062)
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -95.21173858642578)
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -95.55224609375)
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -95.50645446777344)
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -95.28470611572266)
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -95.30632781982422)
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -95.11530303955078)
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -95.19377136230469)
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -95.3666763305664)
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -95.27339172363281)
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -95.56112670898438)
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -95.19661712646484)
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -94.91619110107422)
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -95.28335571289062)
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -95.51421356201172)
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -95.28711700439453)
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -95.03556823730469)
# Best training loss: 2.782827323244419e-05
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -928.5639038085938)
# Best training loss: 1.290501040784875e-05
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -973.3419189453125)
# Best training loss: 8.269522368209437e-06
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -963.1978759765625)
# Best training loss: 7.24452866052161e-06
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -950.9320678710938)
# Best training loss: 1.4974688156144111e-07
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -941.4480590820312)
# Best training loss: 1.8389023352938239e-06
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -938.1552124023438)
# Best training loss: 3.0843877993902424e-06
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -939.5896606445312)
# Best training loss: 2.8073250177840237e-06
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -944.3148193359375)
# Best training loss: 1.63260517638264e-06
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -950.8369140625)
# Best training loss: 3.5593177472037496e-07
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -957.5718383789062)
# Best training loss: 1.4775568502045644e-07
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -964.3753662109375)
# Best training loss: 3.27624178453334e-07
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -970.2243041992188)
# Best training loss: 2.423333569367969e-07
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -975.6309204101562)
# Best training loss: 1.0290362979503698e-06
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -979.94482421875)
# Best training loss: 1.2130176401115023e-06
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -983.8319702148438)
# Best training loss: 1.6699966636224417e-06
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -983.1993408203125)
# Best training loss: 6.371914423652925e-06
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -975.7301635742188)
# Best training loss: 6.2973599597171415e-06
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -977.4522705078125)
# Best training loss: 5.444858743430814e-06
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -983.9230346679688)
# Best training loss: 5.110121037432691e-06
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -986.6187744140625)
# Best training loss: 4.192504547972931e-06
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -985.889892578125)
# Best training loss: 3.84416853194125e-06
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -985.4020385742188)
# Best training loss: 4.3576304165071633e-07
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -984.7735595703125)
# Best training loss: 2.2200554212759016e-06
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -984.5996704101562)
# Best training loss: 1.2093728400941473e-06
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -984.6697998046875)
# Best training loss: 8.042368904170871e-07
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -984.7646484375)
# Best training loss: 1.6751549765103846e-06
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -985.461181640625)
# Best training loss: 1.950730620592367e-06
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -986.16796875)
# Best training loss: 1.6378575082853786e-06
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -987.2315673828125)
# Best training loss: 1.480475702919648e-06
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -988.262451171875)
# Best training loss: 1.2671467857217067e-06
# ('epoch: %s %s  loss: %s', 30, 'TRAIN', -988.6396484375)
# Best training loss: 5.427108931144176e-07
# ('epoch: %s %s  loss: %s', 31, 'TRAIN', -988.0159301757812)
# Best training loss: 1.9459689326595253e-07
# ('epoch: %s %s  loss: %s', 32, 'TRAIN', -985.8197631835938)
# Best training loss: 1.437726524500249e-07
# ('epoch: %s %s  loss: %s', 33, 'TRAIN', -985.502197265625)
# Best training loss: 3.3376210240021464e-07
# ('epoch: %s %s  loss: %s', 34, 'TRAIN', -985.7381591796875)
# Best training loss: 7.057626021378383e-07
# ('epoch: %s %s  loss: %s', 35, 'TRAIN', -988.033935546875)
# Best training loss: 6.633251246057625e-07
# ('epoch: %s %s  loss: %s', 36, 'TRAIN', -988.9445190429688)
# Best training loss: 4.98069312016014e-07
# ('epoch: %s %s  loss: %s', 37, 'TRAIN', -988.9730224609375)
# Best training loss: 6.588769565496477e-07
# ('epoch: %s %s  loss: %s', 38, 'TRAIN', -988.1634521484375)
# Best training loss: 8.331918479598244e-07
# ('epoch: %s %s  loss: %s', 39, 'TRAIN', -987.9252319335938)
# Best training loss: 6.451653575823002e-07
# ('epoch: %s %s  loss: %s', 40, 'TRAIN', -987.6278076171875)
# Best training loss: 5.840412882207602e-07
# ('epoch: %s %s  loss: %s', 41, 'TRAIN', -987.8673095703125)
# Best training loss: 5.816256134494324e-07
# ('epoch: %s %s  loss: %s', 42, 'TRAIN', -988.107421875)
# Best training loss: 6.075451892684214e-07
# ('epoch: %s %s  loss: %s', 43, 'TRAIN', -988.3247680664062)
# Best training loss: 6.407200885405473e-07
# ('epoch: %s %s  loss: %s', 44, 'TRAIN', -988.4807739257812)
# Best training loss: 6.727574941578496e-07
# ('epoch: %s %s  loss: %s', 45, 'TRAIN', -989.0326538085938)
# Best training loss: 6.913775223438279e-07
# ('epoch: %s %s  loss: %s', 46, 'TRAIN', -988.7020263671875)
# Best training loss: 7.335697205235192e-07
# ('epoch: %s %s  loss: %s', 47, 'TRAIN', -989.185791015625)
# Best training loss: 7.417241931761964e-07
# ('epoch: %s %s  loss: %s', 48, 'TRAIN', -988.0213623046875)
# Best training loss: 7.356849778261676e-07
# ('epoch: %s %s  loss: %s', 49, 'TRAIN', -987.6343994140625)
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -987.2108764648438)
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -987.42333984375)
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -988.016845703125)
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -987.650146484375)
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -988.5615234375)
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -987.2920532226562)
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -988.1246948242188)
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -988.52978515625)
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -988.1818237304688)
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -987.8917846679688)
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -987.5237426757812)
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -988.638671875)
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -988.5712280273438)
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -987.2184448242188)
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -987.2787475585938)
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -988.7079467773438)
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -988.47314453125)
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -987.9857788085938)
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -988.3115844726562)
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -987.6859130859375)
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -987.7131958007812)
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -989.0254516601562)
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -988.2996215820312)
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -988.815673828125)
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -988.2120361328125)
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -987.6349487304688)
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -988.3751220703125)
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -988.4769287109375)
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -988.0137939453125)
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -987.74365234375)
# Best training loss: 3.741149839697755e-06
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -9317.41796875)
# Best training loss: 1.0813373592100106e-06
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -9877.8486328125)
# Best training loss: 4.3311354147590464e-07
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -9904.9521484375)
# Best training loss: 2.8762505621671153e-07
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -9891.5419921875)
# Best training loss: 3.071839671520138e-07
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -9860.6884765625)
# Best training loss: 1.8043888871943636e-07
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -9828.73046875)
# Best training loss: 2.7235921606916236e-07
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -9798.220703125)
# Best training loss: 1.1808830180370933e-07
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -9776.306640625)
# Best training loss: 2.4641062168484495e-07
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -9763.375)
# Best training loss: 9.159929703628222e-08
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -9760.224609375)
# Best training loss: 4.06647515660552e-08
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -9765.4365234375)
# Best training loss: 4.3756362089197864e-08
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -9776.4873046875)
# Best training loss: 4.763882444080991e-08
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -9792.140625)
# Best training loss: 2.591282566299924e-08
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -9810.302734375)
# Best training loss: 1.2838327734243649e-07
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -9829.2626953125)
# Best training loss: 4.181403028269415e-07
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -9848.119140625)
# Best training loss: 1.9203871204354073e-07
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -9866.484375)
# Best training loss: 4.92967267007316e-08
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -9882.650390625)
# Best training loss: 6.153097587002776e-08
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -9897.9580078125)
# Best training loss: 1.435735441646102e-07
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -9911.3486328125)
# Best training loss: 1.9114425242605648e-07
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -9923.4541015625)
# Best training loss: 2.852173395240243e-07
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -9935.07421875)
# Best training loss: 4.179468930942676e-07
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -9943.9462890625)
# Best training loss: 3.911728185812535e-07
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -9952.15234375)
# Best training loss: 4.174904688625247e-07
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -9958.630859375)
# Best training loss: 3.6261184277464054e-07
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -9962.572265625)
# Best training loss: 3.068109890591586e-07
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -9966.48046875)
# Best training loss: 3.2758879342509317e-07
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -9961.1201171875)
# Best training loss: 3.77684813201995e-07
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -9937.521484375)
# Best training loss: 4.0078043639368843e-07
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -9944.4404296875)
# Best training loss: 4.753127029744064e-07
# ('epoch: %s %s  loss: %s', 30, 'TRAIN', -9964.2841796875)
# Best training loss: 4.793722041540605e-07
# ('epoch: %s %s  loss: %s', 31, 'TRAIN', -9967.3232421875)
# Best training loss: 2.3344129829183657e-07
# ('epoch: %s %s  loss: %s', 32, 'TRAIN', -9966.5361328125)
# Best training loss: 3.6379656620511014e-08
# ('epoch: %s %s  loss: %s', 33, 'TRAIN', -9965.5576171875)
# Best training loss: 8.652773431094829e-08
# ('epoch: %s %s  loss: %s', 34, 'TRAIN', -9965.58203125)
# Best training loss: 2.4278722321469104e-07
# ('epoch: %s %s  loss: %s', 35, 'TRAIN', -9964.5400390625)
# Best training loss: 1.971574619119565e-07
# ('epoch: %s %s  loss: %s', 36, 'TRAIN', -9963.884765625)
# Best training loss: 1.6213164144573966e-07
# ('epoch: %s %s  loss: %s', 37, 'TRAIN', -9963.4482421875)
# Best training loss: 1.7983985856062645e-07
# ('epoch: %s %s  loss: %s', 38, 'TRAIN', -9962.716796875)
# Best training loss: 2.023804910322724e-07
# ('epoch: %s %s  loss: %s', 39, 'TRAIN', -9962.96875)
# Best training loss: 1.3584940461441875e-07
# ('epoch: %s %s  loss: %s', 40, 'TRAIN', -9963.1689453125)
# Best training loss: 1.8287106229308847e-07
# ('epoch: %s %s  loss: %s', 41, 'TRAIN', -9964.2001953125)
# Best training loss: 1.5167054812081915e-07
# ('epoch: %s %s  loss: %s', 42, 'TRAIN', -9964.6494140625)
# Best training loss: 3.5015693811146775e-07
# ('epoch: %s %s  loss: %s', 43, 'TRAIN', -9965.669921875)
# Best training loss: 2.5872793685266515e-07
# ('epoch: %s %s  loss: %s', 44, 'TRAIN', -9966.9921875)
# Best training loss: 5.333084018843692e-08
# ('epoch: %s %s  loss: %s', 45, 'TRAIN', -9968.80859375)
# Best training loss: 1.1492859997019877e-08
# ('epoch: %s %s  loss: %s', 46, 'TRAIN', -9969.96484375)
# Best training loss: 2.507782603800024e-08
# ('epoch: %s %s  loss: %s', 47, 'TRAIN', -9970.2685546875)
# Best training loss: 5.8543832892610226e-08
# ('epoch: %s %s  loss: %s', 48, 'TRAIN', -9970.298828125)
# Best training loss: 4.0876397378042384e-08
# ('epoch: %s %s  loss: %s', 49, 'TRAIN', -9972.3447265625)
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -9968.2080078125)
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -9970.5400390625)
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -9971.9404296875)
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -9969.45703125)
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -9972.1904296875)
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -9966.37890625)
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -9973.31640625)
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -9970.0302734375)
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -9971.23046875)
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -9968.626953125)
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -9970.119140625)
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -9971.89453125)
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -9971.23046875)
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -9968.3486328125)
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -9968.9052734375)
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -9973.0361328125)
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -9972.232421875)
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -9967.6513671875)
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -9972.052734375)
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -9971.2294921875)
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -9971.2900390625)
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -9973.22265625)
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -9972.6162109375)
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -9970.408203125)
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -9972.302734375)
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -9972.56640625)
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -9971.3203125)
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -9971.6982421875)
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -9968.30859375)
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -9970.388671875)

# %%
vals = []
for i in range(5):
    vals.append([x.item() for x in l[i][-1]["training_loss"]])
print(vals)
# Out:
# [[0.011783059686422348, 0.008362729102373123, 0.005088452249765396, 0.002478755544871092, 0.0016971257282420993, 0.004782459232956171, 0.0038413279689848423, 0.0010714181698858738, 0.0009518689475953579, 0.0003384836600162089, 4.810025347978808e-05, 0.00027611322002485394, 0.00027410921757109463, 2.866076465579681e-05, 0.000560365617275238, 9.327873704023659e-05, 0.0001728117058519274, 0.00027882130234502256, 0.0011360283242538571, 0.0015398822724819183, 7.633132190676406e-05, 0.00046782338176853955, 0.00016900530317798257, 0.0011065606959164143, 1.5077463103807531e-05, 2.0867886632913724e-05, 0.0005621925229206681, 0.0007184197893366218, 0.004241867456585169, 0.000624398177023977, 0.001106373150832951, 0.0027537152636796236, 0.0034807969350367785, 0.000652517715934664, 0.00279984506778419, 7.953072054078802e-05, 0.011783527210354805, 0.0010007467353716493, 0.0048119621351361275, 0.005265301559120417, 0.0037405602633953094, 0.0025188052095472813, 0.00200220150873065, 0.0007375534623861313, 0.0001623880089027807, 0.003189264563843608, 0.0005753007717430592, 0.0013162401737645268, 0.0023964201100170612, 0.009837175719439983], [0.00782895740121603, 0.005621763877570629, 0.0018948247889056802, 0.0005558850825764239, 0.00114988605491817, 0.00016845008940435946, 0.00032053078757598996, 0.00014130568888504058, 0.00044278628774918616, 3.4319698897888884e-05, 0.00010464679508004338, 8.07737887953408e-05, 0.00014553854998666793, 6.994636123636155e-07, 4.324788460507989e-05, 0.00015830011398065835, 9.008923370856792e-05, 3.0071916626184247e-05, 1.1344117410772014e-05, 1.2623493603314273e-05, 3.8720318116247654e-05, 0.00014538472169078887, 0.0002464077842887491, 5.497313031810336e-05, 0.00011020042438758537, 0.00012299721129238605, 0.000334242737153545, 0.00026654297835193574, 0.0001469844428356737, 0.0004018619074486196, 0.0003800018166657537, 0.000155445042764768, 0.0003799194237217307, 0.0004334193654358387, 0.0004357562283985317, 0.0005033113993704319, 0.00017717492301017046, 9.644091915106401e-05, 0.0005915309302508831, 0.0003719687520060688, 9.311331268690992e-06, 0.0002746305544860661, 0.00024480876163579524, 0.0002029769093496725, 0.00017299554019700736, 7.991002348717302e-05, 4.312305463827215e-06, 1.7048947483999655e-05, 0.00012690412404481322, 0.000253411999437958], [0.0013318659039214253, 0.0003019886207766831, 2.6268110104865627e-06, 3.316187212476507e-05, 8.375098695978522e-05, 2.377209602855146e-05, 3.7282406992744654e-06, 6.219500846782466e-06, 7.858456228859723e-06, 1.8700658984016627e-05, 3.8177451642695814e-05, 3.2071853638626635e-05, 3.309032535980805e-06, 1.0155018571822438e-05, 1.768807487678714e-05, 2.969769229821395e-05, 5.934484215686098e-05, 7.273950814123964e-06, 3.278556323493831e-05, 3.934730193577707e-05, 1.957530366780702e-05, 8.479324606014416e-06, 3.2784566883492516e-06, 1.0676475312720868e-06, 1.8114486977083288e-07, 1.3806393326376565e-06, 6.048726390872616e-06, 1.5806455849087797e-05, 2.8341215511318296e-05, 2.8077636670786887e-05, 1.990880946323159e-06, 1.755796438374091e-05, 2.171259984606877e-05, 8.65251786308363e-06, 1.7045931599568576e-05, 2.7081870939582586e-05, 2.277675775985699e-05, 1.899164817587007e-05, 8.517557034792844e-06, 1.2959404557477683e-05, 3.3752563467714936e-05, 2.9694117984035984e-05, 9.669748578744475e-06, 5.380805419008539e-07, 1.2658625792028033e-06, 7.280268164322479e-06, 1.1585577340156306e-05, 1.152425647887867e-05, 4.808752692042617e-06, 3.2728524956837646e-07], [2.782827323244419e-05, 1.290501040784875e-05, 8.269522368209437e-06, 7.24452866052161e-06, 1.4974688156144111e-07, 1.8389023352938239e-06, 3.0843877993902424e-06, 2.8073250177840237e-06, 1.63260517638264e-06, 3.5593177472037496e-07, 1.4775568502045644e-07, 3.27624178453334e-07, 2.423333569367969e-07, 1.0290362979503698e-06, 1.2130176401115023e-06, 1.6699966636224417e-06, 6.371914423652925e-06, 6.2973599597171415e-06, 5.444858743430814e-06, 5.110121037432691e-06, 4.192504547972931e-06, 3.84416853194125e-06, 4.3576304 ...

# %%
import matplotlib.pyplot as plt

# Combine the lists
labels = ["1", "10", "100", "1000", "10000"]#, "10", "15", "20"]
colors = ["blue", "orange", "green", "red","purple"]#, "yellow"]

# Plot the data
xax = range(1,51,1)
for i, (acc, label, color) in enumerate(zip(vals, labels, colors)):
    plt.plot(xax,acc, label=label, color=color)

# Add a horizontal line at y = -1
plt.axhline(y=-0, color="black", linestyle="--")

# Add labels and legend
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss for scaled C")
plt.legend()

# SNOOP = [1, 3, 6, 30, 60]
# for idx in SNOOP:
#     for i in (acc_lists1):
#         k = i
#         k = sorted(k)
#         print(sum(k[:idx])/idx)

# %%
import matplotlib.pyplot as plt
import numpy as np
# Combine the lists
labels = ["1", "0.5", "0.2"]#, "10", "15", "20"]
colors = ["blue", "orange", "green"]#, "red", "purple", "yellow"]
d_list = [np.array(out_dicts1[0][-1]["elbo"])+100000, np.array(out_dicts1[1][-1]["elbo"])+100000, np.array(out_dicts1[2][-1]["elbo"])+100000]
# Plot the data
for i, (acc, label, color) in enumerate(zip(d_list, labels, colors)):
    plt.plot(acc, label=label, color=color)

# Add a horizontal line at y = -1
plt.axhline(y=-0, color="black", linestyle="--")

# Add labels and legend
plt.yscale('log')
plt.xlabel("Iteration")
plt.ylabel("Loss (symlog)")
plt.title("Breast cancer ELBO loss")
plt.legend()

# %%
import matplotlib.pyplot as plt

# Combine the lists
labels = ["4", "6", "8", "10", "15", "20"]
colors = ["blue", "orange", "green", "red", "purple", "yellow"]

# Plot the data
for i, (acc, label, color) in enumerate(zip(acc_lists1, labels, colors)):
    plt.plot(acc, label=label, color=color)

# Add a horizontal line at y = -1
plt.axhline(y=-0, color="black", linestyle="--")

# Add labels and legend
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss for different dimensions, σ = 100")
plt.legend()

# Show the plot
plt.show()

# %%
div = 1000
funnel_config.trainer.epochs = 300
acc_lists2 = []
out_dicts2 = []
for div in [1, 0.5, 0.2]:
    funnel_config = set_task(funnel_config, task, div, c)
    funnel_config.model.input_dim = 9
    out_dict = train_dds(funnel_config)
    out_dicts2.append(out_dict)
    acc_lists2.append([x.item() for x in out_dict[-1]["training_loss"]])

# %%
import matplotlib.pyplot as plt

# Combine the lists
labels = ["4", "6", "8", "10", "15", "20"]
colors = ["blue", "orange", "green", "red", "purple", "yellow"]

# Plot the data
for i, (acc, label, color) in enumerate(zip(acc_lists2, labels, colors)):
    plt.plot(acc, label=label, color=color)

# Add a horizontal line at y = -1
plt.axhline(y=-0, color="black", linestyle="--")

# Add labels and legend
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss for different dimensions, σ = 1000")
plt.legend()

# Show the plot
plt.show()

# %%
from utility_func import *
import visualisation
plot_training_loss(out_dict[-1]["elbo"])
print(out_dict[-1]["elbo"][-1])
visualisation.heat_2d(out_dict)

# %%
out_dict[-1].keys()

# %%
onp.mean(out_dict[-1]["is_eval"])

# %%
onp.mean(out_dict[-1]["pf_eval"])

# %%
out_dict[-1]["pf_eval"]

# %%
import matplotlib.pyplot as plt
import numpy as np

loss_list1, loss_list2, loss_list3 = [], [], []

for i in acc_lists:
    #loss_list1.append(np.log(min(i)))
    loss_list1.append(min(i))

for i in acc_lists1:
    #loss_list2.append(np.log(min(i)))
    loss_list2.append(min(i))

for i in acc_lists2:
    #loss_list3.append(np.log(min(i)))
    loss_list3.append(min(i))

# Combine the lists
loss_lists = [loss_list1, loss_list2, loss_list3]
labels = ['σ = 10', 'σ = 100', 'σ = 1000']
colors = ['blue', 'orange', 'green']

# Custom x-axis labels
x_labels = ["4", "6", "8", "10", "15", "20"]

# Plot the data
for i, (loss, label, color) in enumerate(zip(loss_lists, labels, colors)):
    plt.plot(x_labels, loss, label=label, color=color, marker="o")

# Add labels and legend
plt.yscale('log')
plt.xlabel("X-axis Label")
plt.ylabel("Loss")
plt.title("Loss vs. X-axis Label")
plt.legend()

# Show the plot
plt.show()

# %%
funnel_config.model.reference_process_key

# %%
print(out_dict[-1]["aug"].shape)

# %%
import matplotlib.pyplot as plt

#ode_targ = out_dict[-1]["aug_ode"][:, -1,:2]
sde_targ = out_dict[-1]["aug"][:, -1,:2]

#plt.plot(ode_targ[:, 0], abs(ode_targ[:, 1]), ".", alpha=0.4)
plt.plot(sde_targ[:, 0])#, sde_targ[:, 1], ".", alpha=0.4)
#print(onp.mean(sde_targ[:, 0]))

# %%
import numpy as np
data_x = []
data_fx = []
for sample in out_dict[-1]["aug"]:
    x = sample[-1][:input_dim-1]
    fx = abs(sample[-1][input_dim-1])
    data_x.append(x)
    data_fx.append(fx)

m = np.argmax(data_fx)
print(f"weights: {data_x[m]}")


# Create a list of tuples containing x, y, and z values
combined_data = zip(data_x, data_fx)

# Sort the combined data based on the z values in descending order
sorted_data = sorted(combined_data, key=lambda t: t[1], reverse=True)

# Unzip the sorted data back into separate x, y, and z lists
data_x_sorted, data_fx_sorted = zip(*sorted_data)

best = np.array(list(zip(data_x_sorted, data_fx_sorted)))[:100]
# avg = np.mean(best, axis=0)
# v, w = avg
# print(np.sin(3*np.pi*v) + (v - 1)**2 * (1+np.sin(3*np.pi*w)**2) + (w-1)**2 * (1 + np.sin(2*np.pi*w)**2))
# print(avg)
#print(best)
# for v,w in best:
#     v = np.sin(3*np.pi*v) + (v - 1)**2 * (1+np.sin(3*np.pi*w)**2) + (w-1)**2 * (1 + np.sin(2*np.pi*w)**2)
#     print(v)
from experimental.xor_t import xor_task
task = xor_task()
b = 1
w = None
print(len(data_x))
for weights in data_x:
#for weights, _ in best:
    l = task.get_loss(weights)
    #print(l)
    if l < b:
        b = l
        w = weights

print(b, w)

# %%
from visualisation import *

heat_2d(out_dict, save_name=save_name, sde=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = []
for sample in out_dict[-1]["aug"]:
    s = sample[-1]
    data.append(s)

# Compute the histogram values
hist, bin_edges = np.histogram(data, bins=100)

# Compute the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Create a line plot using Seaborn
sns.lineplot(x=bin_centers, y=hist)

# Set the x and y axis labels
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.axvline(x=0, color='red', linestyle='--', label='x=0.3', alpha=0.5)

# Show the plot
plt.show()

# %%
from dds.targets.toy_targets import *

car = carillo_target_class()
x_values = np.linspace(-10, 10, 1000)

# Compute the corresponding y values
# using the provided function
y_values = np.exp(-car.f(x_values) / 10)

#y_values = -norm.logpdf(y_values,loc=0., scale=1.)

# Create the plot
plt.plot(x_values, y_values)
plt.xlabel("v")
plt.ylabel("f(v)")
plt.title("Plot of the function f(v)")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from dds.targets.toy_targets import *


def temp(x):
    tc = levy_target_class(0,0)
    k = np.exp(-tc.f(x)/10) * 1000
    return k

def rosenbrock_function(x):
    return np.exp(-((1 - x[0])**2 + 100 * (x[1] - x[0]**2)**2)/0.01)

def rastrigin_function(x, A=10):
    n = len(x)
    return np.exp(-(A * n + np.sum(x**2 - A * np.cos(2 * np.pi * x)))/1)

# Create a grid of points for the plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the Rosenbrock function for each point in the grid
Z = np.array([temp(np.array([x, y])) for x, y in zip(np.ravel(X), np.ravel(Y))])
Z = Z.reshape(X.shape)

# Create a contour plot
plt.figure()
plt.contourf(X, Y, Z, levels=100, cmap='jet')
plt.colorbar()
plt.title('Rosenbrock Function')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %%
import numpy as np
import jax.numpy as jnp
from jax.scipy.special import logsumexp
import matplotlib.pyplot as plt

def euclidean_distance_einsum(x, y):
    """Efficiently calculates the euclidean distance between vectors in two mats.


    Args:
      x: first matrix (nxd)
      y: second matrix (mxd)

    Returns:
      pairwise distance matrix (nxm)
    """
    xx = jnp.einsum('ij,ij->i', x, x)[:, jnp.newaxis]
    yy = jnp.einsum('ij,ij->i', y, y)
    xy = 2 * jnp.dot(x, y.T)
    out = xx + yy - xy

    return out

def log_p_pure(x):
    """Gaussian mixture density on well like structure.

    Args:
      x: vectors over which to evaluate the density

    Returns:
      nx1 vector containing density evaluations
    """

    mu = 1.0
    sigma2_ = 0.05
    mus_full = np.array([
        [- mu, 0.0],
        [- mu, mu],
        [- mu, -mu],
        [- mu, 2 * mu],
        [- mu, - 2 * mu],
        [mu, 0.0],
        [mu, mu],
        [mu, -mu],
        [mu, 2 * mu],
        [mu, - 2 * mu],
    ])
    dist_to_means = euclidean_distance_einsum(x, mus_full)

    out = logsumexp(-dist_to_means / (0.01 * sigma2_), axis=1)

    return out

#print(log_p_pure(jnp.array([1,2]).reshape(1,2)))

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the Rosenbrock function for each point in the grid
Z = np.array([log_p_pure(np.array([x, y]).reshape(1,2)) for x, y in zip(np.ravel(X), np.ravel(Y))])
Z = Z.reshape(X.shape)

# Create a contour plot
plt.figure()
plt.contourf(X, Y, Z, levels=100, cmap='jet')
plt.colorbar()
plt.title('Rosenbrock Function')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()
