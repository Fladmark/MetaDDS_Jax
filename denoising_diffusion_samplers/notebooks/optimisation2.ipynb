# %%
from dds.configs.config import set_task, get_config
from dds.train_dds import train_dds

import numpy as onp

# %%
funnel_config = get_config()

# Time and step settings (Need to be done before calling set_task)
funnel_config.model.tfinal = 6.4
funnel_config.model.dt = 0.05 #0.05

if funnel_config.model.reference_process_key == "oudstl":
    funnel_config.model.step_scheme_key = "cos_sq"

from dds.targets.toy_targets import get_attr
### SET TASK
task = "moons"
div = 10
c = 100000

# div, e, other_dim = get_attr()
# div = str(div).replace(".", "")
# e = str(e).replace(".", "")
#
# save_name = f"{task}_s{div}_plus{e}_od{other_dim}"


funnel_config = set_task(funnel_config, task, div, c)
funnel_config.model.reference_process_key = "oudstl"

# funnel_config.model.reference_process_key = "pisstl"
# funnel_config.model.step_scheme_key = "uniform"

# exp_dec
# cos_sq
# uniform
# last_small
# linear_dds
# linear
# uniform_dds

if funnel_config.model.reference_process_key == "oudstl":
    funnel_config.model.step_scheme_key = "cos_sq"
    
    # Opt setting for funnel
    funnel_config.model.sigma = 1.075
    funnel_config.model.alpha = 0.6875
    funnel_config.model.m = 1.0
        
    # Path opt settings    
    funnel_config.model.exp_dds = False


funnel_config.model.stl = False
funnel_config.model.detach_stl_drift = False

# funnel_config.model.stl = True
# funnel_config.model.detach_stl_drift = True

funnel_config.trainer.notebook = True
funnel_config.trainer.epochs = 50
# Opt settings we use
# funnel_config.trainer.learning_rate = 0.0001
funnel_config.trainer.learning_rate = 1 * 10**(-3)
funnel_config.trainer.lr_sch_base_dec = 0.90 # For funnel

# %%
funnel_config.trainer.epochs = 300
acc_lists1 = []
val_lists1 = []
out_dicts1 = []
task = "moons"
for div in [1, 0.5, 0.2]:
    funnel_config = set_task(funnel_config, task, div, c)
    funnel_config.model.input_dim = 41
    out_dict = train_dds(funnel_config)
    out_dicts1.append(out_dict)
    acc_lists1.append([x.item() for x in out_dict[-1]["training_loss"]])
    val_lists1.append([x.item() for x in out_dict[-1]["validation_loss"]])
# Out:
# Best training loss: 0.4502979516983032
# Best validation loss: 0.6275451183319092
# Best training accuracy: 0.538599967956543
# Best validation accuracy: 0.5863999724388123
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -32471.36328125)
# Best training loss: 0.35456228256225586
# Best validation loss: 0.5711200833320618
# Best training accuracy: 0.5679999589920044
# Best validation accuracy: 0.7603999972343445
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -38938.2734375)
# Best training loss: 0.4491451382637024
# Best validation loss: 0.5346462726593018
# Best training accuracy: 0.7197999954223633
# Best validation accuracy: 0.7655999660491943
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -43859.6640625)
# Best training loss: 0.39019855856895447
# Best validation loss: 0.4946575164794922
# Best training accuracy: 0.7239999771118164
# Best validation accuracy: 0.7371999621391296
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -43972.77734375)
# Best training loss: 0.37651342153549194
# Best validation loss: 0.4113198220729828
# Best training accuracy: 0.8001999855041504
# Best validation accuracy: 0.8323999643325806
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -50121.296875)
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -50199.5625)
# Best training loss: 0.23976904153823853
# Best validation loss: 0.38036787509918213
# Best training accuracy: 0.8069999814033508
# Best validation accuracy: 0.8907999992370605
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -49826.3671875)
# Best training loss: 0.33443087339401245
# Best validation loss: 0.3692246377468109
# Best training accuracy: 0.8763999938964844
# Best validation accuracy: 0.8799999952316284
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -48244.8046875)
# Best training loss: 0.3369847536087036
# Best validation loss: 0.39327406883239746
# Best training accuracy: 0.598800003528595
# Best validation accuracy: 0.8935999870300293
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -47948.59375)
# Best training loss: 0.38438528776168823
# Best validation loss: 0.4846496880054474
# Best training accuracy: 0.7841999530792236
# Best validation accuracy: 0.8151999711990356
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -45894.859375)
# Best training loss: 0.39093947410583496
# Best validation loss: 0.48569154739379883
# Best training accuracy: 0.6011999845504761
# Best validation accuracy: 0.7587999701499939
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -47699.83203125)
# Best training loss: 0.3068268299102783
# Best validation loss: 0.4526262581348419
# Best training accuracy: 0.7825999855995178
# Best validation accuracy: 0.8251999616622925
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -49089.1875)
# Best training loss: 0.2858738601207733
# Best validation loss: 0.4762246608734131
# Best training accuracy: 0.7053999900817871
# Best validation accuracy: 0.8136000037193298
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -50548.06640625)
# Best training loss: 0.381641149520874
# Best validation loss: 0.4674207270145416
# Best training accuracy: 0.7321999669075012
# Best validation accuracy: 0.8823999762535095
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -52181.1171875)
# Best training loss: 0.31469202041625977
# Best validation loss: 0.47692421078681946
# Best training accuracy: 0.7662000060081482
# Best validation accuracy: 0.7179999947547913
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -51433.6875)
# Best training loss: 0.3537127375602722
# Best validation loss: 0.4661371111869812
# Best training accuracy: 0.5741999745368958
# Best validation accuracy: 0.7967999577522278
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -50985.640625)
# Best training loss: 0.3356574475765228
# Best validation loss: 0.47560223937034607
# Best training accuracy: 0.724399983882904
# Best validation accuracy: 0.798799991607666
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -50901.98828125)
# Best training loss: 0.3556159734725952
# Best validation loss: 0.49150046706199646
# Best training accuracy: 0.7049999833106995
# Best validation accuracy: 0.7971999645233154
# ('epoch: %s %s  loss: %s', 30, 'TRAIN', -49029.99609375)
# Best training loss: 0.3793720602989197
# Best validation loss: 0.4862515926361084
# Best training accuracy: 0.5953999757766724
# Best validation accuracy: 0.7823999524116516
# ('epoch: %s %s  loss: %s', 31, 'TRAIN', -47728.0234375)
# Best training loss: 0.36772996187210083
# Best validation loss: 0.5576180815696716
# Best training accuracy: 0.6003999710083008
# Best validation accuracy: 0.7152000069618225
# ('epoch: %s %s  loss: %s', 32, 'TRAIN', -48287.83203125)
# Best training loss: 0.420409619808197
# Best validation loss: 0.47728607058525085
# Best training accuracy: 0.6805999875068665
# Best validation accuracy: 0.7807999849319458
# ('epoch: %s %s  loss: %s', 33, 'TRAIN', -48139.44921875)
# Best training loss: 0.3783385157585144
# Best validation loss: 0.49330368638038635
# Best training accuracy: 0.7019999623298645
# Best validation accuracy: 0.764799952507019
# ('epoch: %s %s  loss: %s', 34, 'TRAIN', -50567.23046875)
# Best training loss: 0.36835095286369324
# Best validation loss: 0.5170609951019287
# Best training accuracy: 0.7583999633789062
# Best validation accuracy: 0.7683999538421631
# ('epoch: %s %s  loss: %s', 35, 'TRAIN', -50040.77734375)
# Best training loss: 0.3486713767051697
# Best validation loss: 0.5046700835227966
# Best training accuracy: 0.5945999622344971
# Best validation accuracy: 0.7471999526023865
# ('epoch: %s %s  loss: %s', 36, 'TRAIN', -50991.19921875)
# Best training loss: 0.29444536566734314
# Best validation loss: 0.5152868032455444
# Best training accuracy: 0.599399983882904
# Best validation accuracy: 0.7455999851226807
# ('epoch: %s %s  loss: %s', 37, 'TRAIN', -50655.0234375)
# Best training loss: 0.3044493496417999
# Best validation loss: 0.5282254219055176
# Best training accuracy: 0.698199987411499
# Best validation accuracy: 0.7287999987602234
# ('epoch: %s %s  loss: %s', 38, 'TRAIN', -51496.49609375)
# Best training loss: 0.3162824809551239
# Best validation loss: 0.5422019362449646
# Best training accuracy: 0.6829999685287476
# Best validation accuracy: 0.7195999622344971
# ('epoch: %s %s  loss: %s', 39, 'TRAIN', -50964.30078125)
# Best training loss: 0.2654835879802704
# Best validation loss: 0.5521734952926636
# Best training accuracy: 0.5884000062942505
# Best validation accuracy: 0.7084000110626221
# ('epoch: %s %s  loss: %s', 40, 'TRAIN', -50201.78125)
# Best training loss: 0.2659543752670288
# Best validation loss: 0.5524515509605408
# Best training accuracy: 0.5867999792098999
# Best validation accuracy: 0.712399959564209
# ('epoch: %s %s  loss: %s', 41, 'TRAIN', -51840.6484375)
# Best training loss: 0.3189713954925537
# Best validation loss: 0.5401055216789246
# Best training accuracy: 0.6747999787330627
# Best validation accuracy: 0.722000002861023
# ('epoch: %s %s  loss: %s', 42, 'TRAIN', -54219.640625)
# Best training loss: 0.32638171315193176
# Best validation loss: 0.537991464138031
# Best training accuracy: 0.5789999961853027
# Best validation accuracy: 0.7263999581336975
# ('epoch: %s %s  loss: %s', 43, 'TRAIN', -54789.47265625)
# Best training loss: 0.29072731733322144
# Best validation loss: 0.49032410979270935
# Best training accuracy: 0.6647999882698059
# Best validation accuracy: 0.7644000053405762
# ('epoch: %s %s  loss: %s', 44, 'TRAIN', -54977.44140625)
# Best training loss: 0.322928786277771
# Best validation loss: 0.5230111479759216
# Best training accuracy: 0.6947999596595764
# Best validation accuracy: 0.7432000041007996
# ('epoch: %s %s  loss: %s', 45, 'TRAIN', -54169.25)
# Best training loss: 0.2366332709789276
# Best validation loss: 0.5145760178565979
# Best training accuracy: 0.7134000062942505
# Best validation accuracy: 0.7491999864578247
# ('epoch: %s %s  loss: %s', 46, 'TRAIN', -54159.68359375)
# Best training loss: 0.22546151280403137
# Best validation loss: 0.5138091444969177
# Best training accuracy: 0.6863999962806702
# Best validation accuracy: 0.7479999661445618
# ('epoch: %s %s  loss: %s', 47, 'TRAIN', -55797.74609375)
# Best training loss: 0.14653900265693665
# Best validation loss: 0.5044256448745728
# Best training accuracy: 0.6439999938011169
# Best validation accuracy: 0.7551999688148499
# ('epoch: %s %s  loss: %s', 48, 'TRAIN', -58148.78515625)
# Best training loss: 0.2683573365211487
# Best validation loss: 0.5025667548179626
# Best training accuracy: 0.6563999652862549
# Best validation accuracy: 0.7567999958992004
# ('epoch: %s %s  loss: %s', 49, 'TRAIN', -58742.4140625)
# Best training loss: 0.1905074119567871
# Best validation loss: 0.505937397480011
# Best training accuracy: 0.6597999930381775
# Best validation accuracy: 0.7572000026702881
# ('epoch: %s %s  loss: %s', 50, 'TRAIN', -59499.68359375)
# Best training loss: 0.23931410908699036
# Best validation loss: 0.5412271618843079
# Best training accuracy: 0.6714000105857849
# Best validation accuracy: 0.7099999785423279
# ('epoch: %s %s  loss: %s', 51, 'TRAIN', -57357.07421875)
# Best training loss: 0.2400563657283783
# Best validation loss: 0.5238373279571533
# Best training accuracy: 0.6881999969482422
# Best validation accuracy: 0.7439999580383301
# ('epoch: %s %s  loss: %s', 52, 'TRAIN', -57059.75)
# Best training loss: 0.1728479564189911
# Best validation loss: 0.5395642518997192
# Best training accuracy: 0.689799964427948
# Best validation accuracy: 0.7135999798774719
# ('epoch: %s %s  loss: %s', 53, 'TRAIN', -52705.95703125)
# Best training loss: 0.11929728090763092
# Best validation loss: 0.5367399454116821
# Best training accuracy: 0.6887999773025513
# Best validation accuracy: 0.7427999973297119
# ('epoch: %s %s  loss: %s', 54, 'TRAIN', -59083.3984375)
# Best training loss: 0.2402096688747406
# Best validation loss: 0.5426032543182373
# Best training accuracy: 0.6877999901771545
# Best validation accuracy: 0.715999960899353
# ('epoch: %s %s  loss: %s', 55, 'TRAIN', -57747.8828125)
# Best training loss: 0.18364720046520233
# Best validation loss: 0.5173382759094238
# Best training accuracy: 0.6783999800682068
# Best validation accuracy: 0.7519999742507935
# ('epoch: %s %s  loss: %s', 56, 'TRAIN', -57631.859375)
# Best training loss: 0.16657695174217224
# Best validation loss: 0.5190316438674927
# Best training accuracy: 0.7085999846458435
# Best validation accuracy: 0.7491999864578247
# ('epoch: %s %s  loss: %s', 57, 'TRAIN', -55457.23828125)
# Best training loss: 0.25464698672294617
# Best validation loss: 0.5483196377754211
# Best training accuracy: 0.6895999908447266
# Best validation accuracy: 0.7351999878883362
# ('epoch: %s %s  loss: %s', 58, 'TRAIN', -57420.703125)
# Best training loss: 0.0982678085565567
# Best validation loss: 0.5448739528656006
# Best training accuracy: 0.6995999813079834
# Best validation accuracy: 0.717199981212616
# ('epoch: %s %s  loss: %s', 59, 'TRAIN', -57853.671875)
# Best training loss: 0.2541017234325409
# Best validation loss: 0.5379366874694824
# Best training accuracy: 0.7365999817848206
# Best validation accuracy: 0.7432000041007996
# ('epoch: %s %s  loss: %s', 60, 'TRAIN', -59090.78515625)
# Best training loss: 0.22109811007976532
# Best validation loss: 0.5401674509048462
# Best training accuracy: 0.6958000063896179
# Best validation accuracy: 0.7391999959945679
# ('epoch: %s %s  loss: %s', 61, 'TRAIN', -58734.09375)
# Best training loss: 0.26875585317611694
# Best validation loss: 0.5608904361724854
# Best training accuracy: 0.7003999948501587
# Best validation accuracy: 0.7075999975204468
# ('epoch: %s %s  loss: %s', 62, 'TRAIN', -57164.1171875)
# Best training loss: 0.2525182366371155
# Best validation loss: 0.5679095387458801
# Best training accuracy: 0.6973999738693237
# Best validation accuracy: 0.7071999907493591
# ('epoch: %s %s  loss: %s', 63, 'TRAIN', -56821.76171875)
# Best training loss: 0.24970529973506927
# Best validation loss: 0.5634340047836304
# Best training accuracy: 0.6796000003814697
# Best validation accuracy: 0.7427999973297119
# ('epoch: %s %s  loss: %s', 64, 'TRAIN', -58841.078125)
# Best training loss: 0.19050876796245575
# Best validation loss: 0.5761263370513916
# Best training accuracy: 0.6843999624252319
# Best validation accuracy: 0.7087999582290649
# ('epoch: %s %s  loss: %s', 65, 'TRAIN', -59117.921875)
# Best training loss: 0.2482273429632187
# Best validation loss: 0.5771204233169556
# Best training accuracy: 0.6969999670982361
# Best validation accuracy: 0.717199981212616
# ('epoch: %s %s  loss: %s', 66, 'TRAIN', -59276.9609375)
# Best training loss: 0.27927887439727783
# Best validation loss: 0.5964371562004089
# Best training accuracy: 0.7089999914169312
# Best validation accuracy: 0.7051999568939209
# ('epoch: %s %s  loss: %s', 67, 'TRAIN', -58562.00390625)
# Best training loss: 0.10103102773427963
# Best validation loss: 0.606744110584259
# Best training accuracy: 0.6753999590873718
# Best validation accuracy: 0.7175999879837036
# ('epoch: %s %s  loss: %s', 68, 'TRAIN', -57941.1640625)
# Best training loss: 0.24742691218852997
# Best validation loss: 0.6026546955108643
# Best training accuracy: 0.6881999969482422
# Best validation accuracy: 0.7163999676704407
# ('epoch: %s %s  loss: %s', 69, 'TRAIN', -57344.125)
# Best training loss: 0.27303948998451233
# Best validation loss: 0.6080809235572815
# Best training accuracy: 0.696399986743927
# Best validation accuracy: 0.6951999664306641
# ('epoch: %s %s  loss: %s', 70, 'TRAIN', -57609.05859375)
# Best training loss: 0.28810441493988037
# Best validation loss: 0.6207218170166016
# Best training accuracy: 0.6829999685287476
# Best validation accuracy: 0.69159996509552
# ('epoch: %s %s  loss: %s', 71, 'TRAIN', -59228.6640625)
# Best training loss: 0.27933377027511597
# Best validation loss: 0.6598933339118958
# Best training accuracy: 0.6965999603271484
# Best validation accuracy: 0.704800009727478
# ('epoch: %s %s  loss: %s', 72, 'TRAIN', -56735.8203125)
# Best training loss: 0.08541373908519745
# Best validation loss: 0.6404502987861633
# Best training accuracy: 0.7041999697685242
# Best validation accuracy: 0.704800009727478
# ('epoch: %s %s  loss: %s', 73, 'TRAIN', -57583.2578125)
# Best training loss: 0.04452447220683098
# Best validation loss: 0.6139010787010193
# Best training accuracy: 0.7103999853134155
# Best validation accuracy: 0.6991999745368958
# ('epoch: %s %s  loss: %s', 74, 'TRAIN', -59591.26171875)
# Best training loss: 0.23291389644145966
# Best validation loss: 0.6671988368034363
# Best training accuracy: 0.6901999711990356
# Best validation accuracy: 0.7063999772071838
# ('epoch: %s %s  loss: %s', 75, 'TRAIN', -54927.90234375)
# Best training loss: 0.17271891236305237
# Best validation loss: 0.6685468554496765
# Best training accuracy: 0.6937999725341797
# Best validation accuracy: 0.7127999663352966
# ('epoch: %s %s  loss: %s', 76, 'TRAIN', -55587.4453125)
# Best training loss: 0.27340126037597656
# Best validation loss: 0.6335720419883728
# Best training accuracy: 0.6839999556541443
# Best validation accuracy: 0.7051999568939209
# ('epoch: %s %s  loss: %s', 77, 'TRAIN', -59397.203125)
# Best training loss: 0.16090770065784454
# Best validation loss: 0.6442549824714661
# Best training accuracy: 0.6995999813079834
# Best validation accuracy: 0.7059999704360962
# ('epoch: %s %s  loss: %s', 78, 'TRAIN', -59421.80859375)
# Best training loss: 0.07121964544057846
# Best validation loss: 0.6545453071594238
# Best training accuracy: 0.7003999948501587
# Best validation accuracy: 0.7075999975204468
# ('epoch: %s %s  loss: %s', 79, 'TRAIN', -56446.75)
# Best training loss: 0.18679319322109222
# Best validation loss: 0.6694727540016174
# Best training accuracy: 0.6811999678611755
# Best validation accuracy: 0.7039999961853027
# ('epoch: %s %s  loss: %s', 80, 'TRAIN', -57109.00390625)
# Best training loss: 0.1844150722026825
# Best validation loss: 0.6241471767425537
# Best training accuracy: 0.6815999746322632
# Best validation accuracy: 0.704800009727478
# ('epoch: %s %s  loss: %s', 81, 'TRAIN', -59894.75)
# Best training loss: 0.2797871232032776
# Best validation loss: 0.6260873675346375
# Best training accuracy: 0.6937999725341797
# Best validation accuracy: 0.7015999555587769
# ('epoch: %s %s  loss: %s', 82, 'TRAIN', -58849.109375)
# Best training loss: 0.2063949555158615
# Best validation loss: 0.6495506763458252
# Best training accuracy: 0.7026000022888184
# Best validation accuracy: 0.7199999690055847
# ('epoch: %s %s  loss: %s', 83, 'TRAIN', -53701.26171875)
# Best training loss: 0.1135525330901146
# Best validation loss: 0.6382805705070496
# Best training accuracy: 0.6972000002861023
# Best validation accuracy: 0.7195999622344971
# ('epoch: %s %s  loss: %s', 84, 'TRAIN', -57295.76171875)
# Best training loss: 0.1834435909986496
# Best validation loss: 0.6293991804122925
# Best training accuracy: 0.6987999677658081
# Best validation accuracy: 0.7199999690055847
# ('epoch: %s %s  loss: %s', 85, 'TRAIN', -58947.4296875)
# Best training loss: 0.208086296916008
# Best validation loss: 0.6236867308616638
# Best training accuracy: 0.7003999948501587
# Best validation accuracy: 0.7191999554634094
# ('epoch: %s %s  loss: %s', 86, 'TRAIN', -58488.984375)
# Best training loss: 0.25707826018333435
# Best validation loss: 0.6382477283477783
# Best training accuracy: 0.6926000118255615
# Best validation accuracy: 0.7188000082969666
# ('epoch: %s %s  loss: %s', 87, 'TRAIN', -56211.6328125)
# Best training loss: 0.21345975995063782
# Best validation loss: 0.6445132493972778
# Best training accuracy: 0.6972000002861023
# Best validation accuracy: 0.7195999622344971
# ('epoch: %s %s  loss: %s', 88, 'TRAIN', -56671.84375)
# Best training loss: 0.26944682002067566
# Best validation loss: 0.6345992684364319
# Best training accuracy: 0.6723999977111816
# Best validation accuracy: 0.7195999622344971
# ('epoch: %s %s  loss: %s', 89, 'TRAIN', -59542.01953125)
# Best training loss: 0.18101632595062256
# Best validation loss: 0.638237714767456
# Best training accuracy: 0.7067999839782715
# Best validation accuracy: 0.7107999920845032
# ('epoch: %s %s  loss: %s', 90, 'TRAIN', -58373.5859375)
# Best training loss: 0.16960445046424866
# Best validation loss: 0.6544132828712463
# Best training accuracy: 0.6937999725341797
# Best validation accuracy: 0.7199999690055847
# ('epoch: %s %s  loss: %s', 91, 'TRAIN', -57175.66015625)
# Best training loss: 0.261916846036911
# Best validation loss: 0.6396697163581848
# Best training accuracy: 0.6883999705314636
# Best validation accuracy: 0.7195999622344971
# ('epoch: %s %s  loss: %s', 92, 'TRAIN', -59873.43359375)
# Best training loss: 0.13479763269424438
# Best validation loss: 0.6260684132575989
# Best training accuracy: 0.7008000016212463
# Best validation accuracy: 0.7195999622344971
# ('epoch: %s %s  loss: %s', 93, 'TRAIN', -59774.1328125)
# Best training loss: 0.18099020421504974
# Best validation loss: 0.6275860071182251
# Best training accuracy: 0.698199987411499
# Best validation accuracy: 0.7184000015258789
# ('epoch: %s %s  loss: %s', 94, 'TRAIN', -58272.73046875)
# Best training loss: 0.19625699520111084
# Best validation loss: 0.6350964903831482
# Best training accuracy: 0.699400007724762
# Best validation accuracy: 0.7203999757766724
# ('epoch: %s %s  loss: %s', 95, 'TRAIN', -58252.6953125)
# Best training loss: 0.22076740860939026
# Best validation loss: 0.6338654160499573
# Best training accuracy: 0.686199963092804
# Best validation accuracy: 0.7188000082969666
# ('epoch: %s %s  loss: %s', 96, 'TRAIN', -57599.82421875)
# Best training loss: 0.27949297428131104
# Best validation loss: 0.6172340512275696
# Best training accuracy: 0.6865999698638916
# Best validation accuracy: 0.7008000016212463
# ('epoch: %s %s  loss: %s', 97, 'TRAIN', -59763.69140625)
# Best training loss: 0.09490495920181274
# Best validation loss: 0.6093399524688721
# Best training accuracy: 0.6941999793052673
# Best validation accuracy: 0.717199981212616
# ('epoch: %s %s  loss: %s', 98, 'TRAIN', -59099.01953125)
# Best training loss: 0.24939477443695068
# Best validation loss: 0.6230579614639282
# Best training accuracy: 0.6953999996185303
# Best validation accuracy: 0.715999960899353
# ('epoch: %s %s  loss: %s', 99, 'TRAIN', -57853.98046875)
# Best training loss: 0.17684859037399292
# Best validation loss: 0.6422330737113953
# Best training accuracy: 0.6987999677658081
# Best validation accuracy: 0.6904000043869019
# ('epoch: %s %s  loss: %s', 100, 'TRAIN', -57029.3984375)
# Best training loss: 0.1723281592130661
# Best validation loss: 0.6297467947006226
# Best training accuracy: 0.699999988079071
# Best validation accuracy: 0.7167999744415283
# ('epoch: %s %s  loss: %s', 101, 'TRAIN', -58875.60546875)
# Best training loss: 0.24159777164459229
# Best validation loss: 0.6214405298233032
# Best training accuracy: 0.710599958896637
# Best validation accuracy: 0.7080000042915344
# ('epoch: %s %s  loss: %s', 102, 'TRAIN', -59531.28515625)
# Best training loss: 0.13231532275676727
# Best validation loss: 0.6129385232925415
# Best training accuracy: 0.6940000057220459
# Best validation accuracy: 0.7135999798774719
# ('epoch: %s %s  loss: %s', 103, 'TRAIN', -60469.453125)
# Best training loss: 0.03084554336965084
# Best validation loss: 0.6355777382850647
# Best training accuracy: 0.7023999691009521
# Best validation accuracy: 0.692799985408783
# ('epoch: %s %s  loss: %s', 104, 'TRAIN', -56962.0078125)
# Best training loss: 0.18268153071403503
# Best validation loss: 0.6402018666267395
# Best training accuracy: 0.6829999685287476
# Best validation accuracy: 0.6923999786376953
# ('epoch: %s %s  loss: %s', 105, 'TRAIN', -57651.23828125)
# Best training loss: 0.169598788022995
# Best validation loss: 0.6295996308326721
# Best training accuracy: 0.7073999643325806
# Best validation accuracy: 0.6935999989509583
# ('epoch: %s %s  loss: %s', 106, 'TRAIN', -57620.5859375)
# Best training loss: 0.2876010537147522
# Best validation loss: 0.6243126392364502
# Best training accuracy: 0.7003999948501587
# Best validation accuracy: 0.6959999799728394
# ('epoch: %s %s  loss: %s', 107, 'TRAIN', -58718.76953125)
# Best training loss: 0.21643798053264618
# Best validation loss: 0.6231827735900879
# Best training accuracy: 0.6783999800682068
# Best validation accuracy: 0.7019999623298645
# ('epoch: %s %s  loss: %s', 108, 'TRAIN', -58013.41796875)
# Best training loss: 0.1614382565021515
# Best validation loss: 0.6276469826698303
# Best training accuracy: 0.6895999908447266
# Best validation accuracy: 0.7135999798774719
# ('epoch: %s %s  loss: %s', 109, 'TRAIN', -56442.140625)
# Best training loss: 0.2550545632839203
# Best validation loss: 0.6180751919746399
# Best training accuracy: 0.6991999745368958
# Best validation accuracy: 0.7071999907493591
# ('epoch: %s %s  loss: %s', 110, 'TRAIN', -58240.0703125)
# Best training loss: 0.256621778011322
# Best validation loss: 0.6146084666252136
# Best training accuracy: 0.6797999739646912
# Best validation accuracy: 0.7055999636650085
# ('epoch: %s %s  loss: %s', 111, 'TRAIN', -58669.32421875)
# Best training loss: 0.24351763725280762
# Best validation loss: 0.6151975393295288
# Best training accuracy: 0.6645999550819397
# Best validation accuracy: 0.7044000029563904
# ('epoch: %s %s  loss: %s', 112, 'TRAIN', -60004.51953125)
# Best training loss: 0.2751227617263794
# Best validation loss: 0.6300982236862183
# Best training accuracy: 0.6809999942779541
# Best validation accuracy: 0.6951999664306641
# ('epoch: %s %s  loss: %s', 113, 'TRAIN', -57779.75)
# Best training loss: 0.1358601152896881
# Best validation loss: 0.63847815990448
# Best training accuracy: 0.6620000004768372
# Best validation accuracy: 0.6931999921798706
# ('epoch: %s %s  loss: %s', 114, 'TRAIN', -57863.03515625)
# Best training loss: 0.1807238757610321
# Best validation loss: 0.6232482194900513
# Best training accuracy: 0.7045999765396118
# Best validation accuracy: 0.6940000057220459
# ('epoch: %s %s  loss: %s', 115, 'TRAIN', -59064.39453125)
# Best training loss: 0.2542322874069214
# Best validation loss: 0.6052888631820679
# Best training accuracy: 0.6818000078201294
# Best validation accuracy: 0.7019999623298645
# ('epoch: %s %s  loss: %s', 116, 'TRAIN', -58994.4140625)
# Best training loss: 0.2622913122177124
# Best validation loss: 0.6149999499320984
# Best training accuracy: 0.6783999800682068
# Best validation accuracy: 0.7167999744415283
# ('epoch: %s %s  loss: %s', 117, 'TRAIN', -58901.4140625)
# Best training loss: 0.19967412948608398
# Best validation loss: 0.6218218207359314
# Best training accuracy: 0.676800012588501
# Best validation accuracy: 0.6976000070571899
# ('epoch: %s %s  loss: %s', 118, 'TRAIN', -58363.87890625)
# Best training loss: 0.12772046029567719
# Best validation loss: 0.6222036480903625
# Best training accuracy: 0.6951999664306641
# Best validation accuracy: 0.715999960899353
# ('epoch: %s %s  loss: %s', 119, 'TRAIN', -57268.1484375)
# Best training loss: 0.1980295032262802
# Best validation loss: 0.6133761405944824
# Best training accuracy: 0.6977999806404114
# Best validation accuracy: 0.7163999676704407
# ('epoch: %s %s  loss: %s',
# Best validation accuracy: 0.7175999879837036
# ('epoch: %s %s  loss: %s', 136, 'TRAIN', -57887.2890625)
# Best training loss: 0.26840364933013916
# Best validation loss: 0.6119200587272644
# Best training accuracy: 0.7015999555587769
# Best validation accuracy: 0.717199981212616
# ('epoch: %s %s  loss: %s', 137, 'TRAIN', -58229.80078125)
# Best training loss: 0.12495347112417221
# Best validation loss: 0.60247403383255
# Best training accuracy: 0.6845999956130981
# Best validation accuracy: 0.7039999961853027
# ('epoch: %s %s  loss: %s', 138, 'TRAIN', -59989.03125)
# Best training loss: 0.12188909947872162
# Best validation loss: 0.6049558520317078
# Best training accuracy: 0.7085999846458435
# Best validation accuracy: 0.7019999623298645
# ('epoch: %s %s  loss: %s', 139, 'TRAIN', -58539.48046875)
# Best training loss: 0.263658344745636
# Best validation loss: 0.6075652241706848
# Best training accuracy: 0.6773999929428101
# Best validation accuracy: 0.7175999879837036
# ('epoch: %s %s  loss: %s', 140, 'TRAIN', -58022.6015625)
# Best training loss: 0.17669552564620972
# Best validation loss: 0.6058496236801147
# Best training accuracy: 0.6785999536514282
# Best validation accuracy: 0.7175999879837036
# ('epoch: %s %s  loss: %s', 141, 'TRAIN', -58944.29296875)
# Best training loss: 0.28638511896133423
# Best validation loss: 0.6039481163024902
# Best training accuracy: 0.6965999603271484
# Best validation accuracy: 0.7175999879837036
# ('epoch: %s %s  loss: %s', 142, 'TRAIN', -58025.09375)
# Best training loss: 0.1773354709148407
# Best validation loss: 0.6076379418373108
# Best training accuracy: 0.7039999961853027
# Best validation accuracy: 0.7163999676704407
# ('epoch: %s %s  loss: %s', 143, 'TRAIN', -58832.95703125)
# Best training loss: 0.08000347018241882
# Best validation loss: 0.6163172125816345
# Best training accuracy: 0.6953999996185303
# Best validation accuracy: 0.717199981212616
# ('epoch: %s %s  loss: %s', 144, 'TRAIN', -58463.03515625)
# Best training loss: 0.267265260219574
# Best validation loss: 0.6158986687660217
# Best training accuracy: 0.7035999894142151
# Best validation accuracy: 0.717199981212616
# ('epoch: %s %s  loss: %s', 145, 'TRAIN', -56169.609375)
# Best training loss: 0.25357306003570557
# Best validation loss: 0.6038146615028381
# Best training accuracy: 0.6845999956130981
# Best validation accuracy: 0.715999960899353
# ('epoch: %s %s  loss: %s', 146, 'TRAIN', -58488.5234375)
# Best training loss: 0.24899858236312866
# Best validation loss: 0.5904839634895325
# Best training accuracy: 0.6987999677658081
# Best validation accuracy: 0.7099999785423279
# ('epoch: %s %s  loss: %s', 147, 'TRAIN', -60221.8359375)
# Best training loss: 0.0740845799446106
# Best validation loss: 0.601030170917511
# Best training accuracy: 0.6959999799728394
# Best validation accuracy: 0.7163999676704407
# ('epoch: %s %s  loss: %s', 148, 'TRAIN', -58316.3125)
# Best training loss: 0.24738144874572754
# Best validation loss: 0.6068108081817627
# Best training accuracy: 0.703000009059906
# Best validation accuracy: 0.7167999744415283
# ('epoch: %s %s  loss: %s', 149, 'TRAIN', -55108.73046875)
# Best training loss: 0.25901252031326294
# Best validation loss: 0.6130193471908569
# Best training accuracy: 0.7085999846458435
# Best validation accuracy: 0.7175999879837036
# ('epoch: %s %s  loss: %s', 150, 'TRAIN', -58734.00390625)
# Best training loss: 0.18571840226650238
# Best validation loss: 0.6093352437019348
# Best training accuracy: 0.6911999583244324
# Best validation accuracy: 0.7027999758720398
# ('epoch: %s %s  loss: %s', 151, 'TRAIN', -59024.90234375)
# Best training loss: 0.24422995746135712
# Best validation loss: 0.6009111404418945
# Best training accuracy: 0.7059999704360962
# Best validation accuracy: 0.7116000056266785
# ('epoch: %s %s  loss: %s', 152, 'TRAIN', -59620.14453125)
# Best training loss: 0.28391969203948975
# Best validation loss: 0.5988478064537048
# Best training accuracy: 0.694599986076355
# Best validation accuracy: 0.7080000042915344
# ('epoch: %s %s  loss: %s', 153, 'TRAIN', -59285.96484375)
# Best training loss: 0.24828088283538818
# Best validation loss: 0.6069217324256897
# Best training accuracy: 0.7039999961853027
# Best validation accuracy: 0.7067999839782715
# ('epoch: %s %s  loss: %s', 154, 'TRAIN', -59040.953125)
# Best training loss: 0.22110936045646667
# Best validation loss: 0.618763267993927
# Best training accuracy: 0.7044000029563904
# Best validation accuracy: 0.7188000082969666
# ('epoch: %s %s  loss: %s', 155, 'TRAIN', -57208.203125)
# Best training loss: 0.20644879341125488
# Best validation loss: 0.6171234250068665
# Best training accuracy: 0.6940000057220459
# Best validation accuracy: 0.7188000082969666
# ('epoch: %s %s  loss: %s', 156, 'TRAIN', -58238.58203125)
# Best training loss: 0.2390890121459961
# Best validation loss: 0.618336021900177
# Best training accuracy: 0.7073999643325806
# Best validation accuracy: 0.7039999961853027
# ('epoch: %s %s  loss: %s', 157, 'TRAIN', -58296.9453125)
# Best training loss: 0.0922965258359909
# Best validation loss: 0.6269238591194153
# Best training accuracy: 0.693399965763092
# Best validation accuracy: 0.717199981212616
# ('epoch: %s %s  loss: %s', 158, 'TRAIN', -58635.546875)
# Best training loss: 0.1027965396642685
# Best validation loss: 0.6323206424713135
# Best training accuracy: 0.6911999583244324
# Best validation accuracy: 0.7155999541282654
# ('epoch: %s %s  loss: %s', 159, 'TRAIN', -57320.5703125)
# Best training loss: 0.30392986536026
# Best validation loss: 0.6251313090324402
# Best training accuracy: 0.6977999806404114
# Best validation accuracy: 0.7167999744415283
# ('epoch: %s %s  loss: %s', 160, 'TRAIN', -58003.47265625)
# Best training loss: 0.2701280117034912
# Best validation loss: 0.6132155060768127
# Best training accuracy: 0.7001999616622925
# Best validation accuracy: 0.7167999744415283
# ('epoch: %s %s  loss: %s', 161, 'TRAIN', -59506.85546875)
# Best training loss: 0.2569921016693115
# Best validation loss: 0.6128097176551819
# Best training accuracy: 0.7035999894142151
# Best validation accuracy: 0.7167999744415283
# ('epoch: %s %s  loss: %s', 162, 'TRAIN', -59370.6640625)
# Best training loss: 0.20026502013206482
# Best validation loss: 0.6250895261764526
# Best training accuracy: 0.7059999704360962
# Best validation accuracy: 0.7167999744415283
# ('epoch: %s %s  loss: %s', 163, 'TRAIN', -58853.67578125)
# Best training loss: 0.24919699132442474
# Best validation loss: 0.6222642064094543
# Best training accuracy: 0.7071999907493591
# Best validation accuracy: 0.7175999879837036
# ('epoch: %s %s  loss: %s', 164, 'TRAIN', -58281.28125)
# Best training loss: 0.23995304107666016
# Best validation loss: 0.6051204800605774
# Best training accuracy: 0.6949999928474426
# Best validation accuracy: 0.7116000056266785
# ('epoch: %s %s  loss: %s', 165, 'TRAIN', -58017.15234375)
# Best training loss: 0.26255249977111816
# Best validation loss: 0.6227597594261169
# Best training accuracy: 0.6904000043869019
# Best validation accuracy: 0.7184000015258789
# ('epoch: %s %s  loss: %s', 166, 'TRAIN', -58601.48828125)
# Best training loss: 0.24594919383525848
# Best validation loss: 0.6242129802703857
# Best training accuracy: 0.6771999597549438
# Best validation accuracy: 0.7184000015258789
# ('epoch: %s %s  loss: %s', 167, 'TRAIN', -59789.015625)
# Best training loss: 0.30332642793655396
# Best validation loss: 0.6198725700378418
# Best training accuracy: 0.6865999698638916
# Best validation accuracy: 0.7039999961853027
# ('epoch: %s %s  loss: %s', 168, 'TRAIN', -58259.55859375)
# Best training accuracy: 0.6965999603271484
# Best validation accuracy: 0.7119999527931213
# ('epoch: %s %s  loss: %s', 182, 'TRAIN', -59941.53125)
# Best training loss: 0.19371828436851501
# Best validation loss: 0.5984082818031311
# Best training accuracy: 0.7077999711036682
# Best validation accuracy: 0.7127999663352966
# ('epoch: %s %s  loss: %s', 183, 'TRAIN', -57707.76953125)
# Best training loss: 0.10655789077281952
# Best validation loss: 0.6241887807846069
# Best training accuracy: 0.7055999636650085
# Best validation accuracy: 0.7051999568939209
# ('epoch: %s %s  loss: %s', 184, 'TRAIN', -58910.19921875)
# Best training loss: 0.22101961076259613
# Best validation loss: 0.6331241726875305
# Best training accuracy: 0.6991999745368958
# Best validation accuracy: 0.7103999853134155
# ('epoch: %s %s  loss: %s', 185, 'TRAIN', -57922.421875)
# Best training loss: 0.2663976848125458
# Best validation loss: 0.6107719540596008
# Best training accuracy: 0.7023999691009521
# Best validation accuracy: 0.7019999623298645
# ('epoch: %s %s  loss: %s', 186, 'TRAIN', -57444.34375)
# Best training loss: 0.2644613981246948
# Best validation loss: 0.5902758836746216
# Best training accuracy: 0.6905999779701233
# Best validation accuracy: 0.7107999920845032
# ('epoch: %s %s  loss: %s', 187, 'TRAIN', -59796.9765625)
# Best training loss: 0.0423019602894783
# Best validation loss: 0.6047702431678772
# Best training accuracy: 0.6851999759674072
# Best validation accuracy: 0.704800009727478
# ('epoch: %s %s  loss: %s', 188, 'TRAIN', -58888.7421875)
# Best training loss: 0.24100208282470703
# Best validation loss: 0.6212779879570007
# Best training accuracy: 0.6825999617576599
# Best validation accuracy: 0.7127999663352966
# ('epoch: %s %s  loss: %s', 189, 'TRAIN', -59475.56640625)
# Best training loss: 0.18476729094982147
# Best validation loss: 0.6582133173942566
# Best training accuracy: 0.7059999704360962
# Best validation accuracy: 0.7044000029563904
# ('epoch: %s %s  loss: %s', 190, 'TRAIN', -57757.28125)
# Best training loss: 0.17158877849578857
# Best validation loss: 0.6354815363883972
# Best training accuracy: 0.6868000030517578
# Best validation accuracy: 0.7003999948501587
# ('epoch: %s %s  loss: %s', 191, 'TRAIN', -58138.5)
# Best training loss: 0.25591522455215454
# Best validation loss: 0.6336984038352966
# Best training accuracy: 0.6819999814033508
# Best validation accuracy: 0.701200008392334
# ('epoch: %s %s  loss: %s', 192, 'TRAIN', -59345.609375)
# Best training loss: 0.10081104934215546
# Best validation loss: 0.635552704334259
# Best training accuracy: 0.694599986076355
# Best validation accuracy: 0.699999988079071
# ('epoch: %s %s  loss: %s', 193, 'TRAIN', -58825.67578125)
# Best training loss: 0.14324268698692322
# Best validation loss: 0.6324585676193237
# Best training accuracy: 0.6931999921798706
# Best validation accuracy: 0.7127999663352966
# ('epoch: %s %s  loss: %s', 194, 'TRAIN', -58617.9296875)
# Best training loss: 0.30397674441337585
# Best validation loss: 0.6398295164108276
# Best training accuracy: 0.6949999928474426
# Best validation accuracy: 0.7003999948501587
# ('epoch: %s %s  loss: %s', 195, 'TRAIN', -58836.89453125)
# Best training loss: 0.19869303703308105
# Best validation loss: 0.6320317983627319
# Best training accuracy: 0.6764000058174133
# Best validation accuracy: 0.699999988079071
# ('epoch: %s %s  loss: %s', 196, 'TRAIN', -59826.765625)
# Best training loss: 0.26862815022468567
# Best validation loss: 0.621134340763092
# Best training accuracy: 0.6987999677658081
# Best validation accuracy: 0.715999960899353
# ('epoch: %s %s  loss: %s', 197, 'TRAIN', -59438.1796875)
# Best training loss: 0.259628027677536
# Best validation loss: 0.6444945931434631
# Best training accuracy: 0.6965999603271484
# Best validation accuracy: 0.6983999609947205
# ('epoch: %s %s  loss: %s', 198, 'TRAIN', -58806.2421875)
# Best training loss: 0.028908027336001396
# Best validation loss: 0.6635332703590393
# Best training accuracy: 0.6883999705314636
# Best validation accuracy: 0.6979999542236328
# ('epoch: %s %s  loss: %s', 199, 'TRAIN', -59246.21875)
# Best training loss: 0.26649582386016846
# Best validation loss: 0.6385685205459595
# Best training accuracy: 0.7008000016212463
# Best validation accuracy: 0.7143999934196472
# ('epoch: %s %s  loss: %s', 200, 'TRAIN', -58198.36328125)
# Best training loss: 0.25213348865509033
# Best validation loss: 0.6393570899963379
# Best training accuracy: 0.7045999765396118
# Best validation accuracy: 0.6995999813079834
# ('epoch: %s %s  loss: %s', 201, 'TRAIN', -58346.25)
# Best training loss: 0.2799881398677826
# Best validation loss: 0.6302168965339661
# Best training accuracy: 0.6821999549865723
# Best validation accuracy: 0.7003999948501587
# ('epoch: %s %s  loss: %s', 202, 'TRAIN', -58596.26171875)
# Best training loss: 0.21205663681030273
# Best validation loss: 0.6289037466049194
# Best training accuracy: 0.6823999881744385
# Best validation accuracy: 0.7023999691009521
# ('epoch: %s %s  loss: %s', 203, 'TRAIN', -59854.171875)
# Best training loss: 0.1248432993888855
# Best validation loss: 0.6384491324424744
# Best training accuracy: 0.6905999779701233
# Best validation accuracy: 0.7031999826431274
# ('epoch: %s %s  loss: %s', 204, 'TRAIN', -58089.0703125)
# Best training loss: 0.30899783968925476
# Best validation loss: 0.6378005146980286
# Best training accuracy: 0.6972000002861023
# Best validation accuracy: 0.704800009727478
# ('epoch: %s %s  loss: %s', 205, 'TRAIN', -58993.66796875)
# Best training loss: 0.17213168740272522
# Best validation loss: 0.615324854850769
# Best training accuracy: 0.6965999603271484
# Best validation accuracy: 0.7075999975204468
# ('epoch: %s %s  loss: %s', 206, 'TRAIN', -59070.73046875)
# Best training loss: 0.23108702898025513
# Best validation loss: 0.6002131104469299
# Best training accuracy: 0.7053999900817871
# Best validation accuracy: 0.7084000110626221
# ('epoch: %s %s  loss: %s', 207, 'TRAIN', -58678.91796875)
# Best training loss: 0.22960226237773895
# Best validation loss: 0.6065879464149475
# Best training accuracy: 0.6869999766349792
# Best validation accuracy: 0.7080000042915344
# ('epoch: %s %s  loss: %s', 208, 'TRAIN', -58174.296875)
# Best training loss: 0.24329541623592377
# Best validation loss: 0.6010391712188721
# Best training accuracy: 0.6854000091552734
# Best validation accuracy: 0.7095999717712402
# ('epoch: %s %s  loss: %s', 209, 'TRAIN', -59074.98046875)
# Best training loss: 0.28082945942878723
# Best validation loss: 0.5877429842948914
# Best training accuracy: 0.7045999765396118
# Best validation accuracy: 0.7080000042915344
# ('epoch: %s %s  loss: %s', 210, 'TRAIN', -59298.40234375)
# Best validation accuracy: 0.7831999659538269
# ('epoch: %s %s  loss: %s', 264, 'TRAIN', -12451.478515625)
# Best training loss: 0.1040152832865715
# Best validation loss: 0.47070935368537903
# Best training accuracy: 0.7823999524116516
# Best validation accuracy: 0.7888000011444092
# ('epoch: %s %s  loss: %s', 265, 'TRAIN', -13109.5078125)
# Best training loss: 0.07900616526603699
# Best validation loss: 0.46845439076423645
# Best training accuracy: 0.7497999668121338
# Best validation accuracy: 0.7924000024795532
# ('epoch: %s %s  loss: %s', 266, 'TRAIN', -12992.3837890625)
# Best training loss: 0.15168386697769165
# Best validation loss: 0.4735400378704071
# Best training accuracy: 0.7795999646186829
# Best validation accuracy: 0.7827999591827393
# ('epoch: %s %s  loss: %s', 267, 'TRAIN', -11882.5048828125)
# Best training loss: 0.052813805639743805
# Best validation loss: 0.47237351536750793
# Best training accuracy: 0.7649999856948853
# Best validation accuracy: 0.7827999591827393
# ('epoch: %s %s  loss: %s', 268, 'TRAIN', -11303.638671875)
# Best training loss: 0.16090886294841766
# Best validation loss: 0.469718337059021
# Best training accuracy: 0.7515999674797058
# Best validation accuracy: 0.7827999591827393
# ('epoch: %s %s  loss: %s', 269, 'TRAIN', -12941.9482421875)
# Best training loss: 0.15369972586631775
# Best validation loss: 0.46212249994277954
# Best training accuracy: 0.7547999620437622
# Best validation accuracy: 0.7947999835014343
# ('epoch: %s %s  loss: %s', 270, 'TRAIN', -13096.75390625)
# Best training loss: 0.12605422735214233
# Best validation loss: 0.4621504843235016
# Best training accuracy: 0.7393999695777893
# Best validation accuracy: 0.795199990272522
# ('epoch: %s %s  loss: %s', 271, 'TRAIN', -12803.7607421875)
# Best training loss: 0.14421693980693817
# Best validation loss: 0.46689578890800476
# Best training accuracy: 0.7663999795913696
# Best validation accuracy: 0.7820000052452087
# ('epoch: %s %s  loss: %s', 272, 'TRAIN', -11825.0244140625)
# Best training loss: 0.028238113969564438
# Best validation loss: 0.4674288034439087
# Best training accuracy: 0.764799952507019
# Best validation accuracy: 0.7823999524116516
# ('epoch: %s %s  loss: %s', 273, 'TRAIN', -11876.015625)
# Best training loss: 0.08519071340560913
# Best validation loss: 0.4640604257583618
# Best training accuracy: 0.767799973487854
# Best validation accuracy: 0.7955999970436096
# ('epoch: %s %s  loss: %s', 274, 'TRAIN', -12076.7001953125)
# Best training loss: 0.12193824350833893
# Best validation loss: 0.45632830262184143
# Best training accuracy: 0.7673999667167664
# Best validation accuracy: 0.7955999970436096
# ('epoch: %s %s  loss: %s', 275, 'TRAIN', -13241.4775390625)
# Best training loss: 0.056870654225349426
# Best validation loss: 0.46323955059051514
# Best training accuracy: 0.7511999607086182
# Best validation accuracy: 0.7888000011444092
# ('epoch: %s %s  loss: %s', 276, 'TRAIN', -12523.6953125)
# Best training loss: 0.06912176311016083
# Best validation loss: 0.46401503682136536
# Best training accuracy: 0.7737999558448792
# Best validation accuracy: 0.7879999876022339
# ('epoch: %s %s  loss: %s',
# Best validation accuracy: 0.7892000079154968
# ('epoch: %s %s  loss: %s', 293, 'TRAIN', -13252.263671875)
# Best training loss: 0.04246295616030693
# Best validation loss: 0.46271923184394836
# Best training accuracy: 0.7759999632835388
# Best validation accuracy: 0.7892000079154968
# ('epoch: %s %s  loss: %s', 294, 'TRAIN', -13110.5439453125)
# Best training loss: 0.1430952250957489
# Best validation loss: 0.46590349078178406
# Best training accuracy: 0.7583999633789062
# Best validation accuracy: 0.7883999943733215
# ('epoch: %s %s  loss: %s', 295, 'TRAIN', -13495.904296875)
# Best training loss: 0.04032313823699951
# Best validation loss: 0.4688175618648529
# Best training accuracy: 0.7401999831199646
# Best validation accuracy: 0.7875999808311462
# ('epoch: %s %s  loss: %s', 296, 'TRAIN', -13051.4140625)
# Best training loss: 0.15006190538406372
# Best validation loss: 0.47423872351646423
# Best training accuracy: 0.7543999552726746
# Best validation accuracy: 0.7919999957084656
# ('epoch: %s %s  loss: %s', 297, 'TRAIN', -12631.9169921875)
# Best training loss: 0.10910247266292572
# Best validation loss: 0.4768725335597992
# Best training accuracy: 0.7565999627113342
# Best validation accuracy: 0.7911999821662903
# ('epoch: %s %s  loss: %s', 298, 'TRAIN', -12892.150390625)
# Best training loss: 0.03504151850938797
# Best validation loss: 0.47643065452575684
# Best training accuracy: 0.7473999857902527
# Best validation accuracy: 0.786799967288971
# ('epoch: %s %s  loss: %s', 299, 'TRAIN', -12383.1630859375)
# 0.82479995
# [0 1 1 ... 1 1 1]
# ('epoch: %s %s  loss: %s', 0, 'TRAIN', -12673.794921875)
# ('epoch: %s %s  loss: %s', 1, 'TRAIN', -13564.0595703125)
# ('epoch: %s %s  loss: %s', 2, 'TRAIN', -12674.298828125)
# ('epoch: %s %s  loss: %s', 3, 'TRAIN', -12412.744140625)
# ('epoch: %s %s  loss: %s', 4, 'TRAIN', -13280.0712890625)
# ('epoch: %s %s  loss: %s', 5, 'TRAIN', -13435.671875)
# ('epoch: %s %s  loss: %s', 6, 'TRAIN', -12735.2646484375)
# ('epoch: %s %s  loss: %s', 7, 'TRAIN', -12521.958984375)
# ('epoch: %s %s  loss: %s', 8, 'TRAIN', -12221.0068359375)
# ('epoch: %s %s  loss: %s', 9, 'TRAIN', -13122.529296875)
# ('epoch: %s %s  loss: %s', 10, 'TRAIN', -12533.275390625)
# ('epoch: %s %s  loss: %s', 11, 'TRAIN', -12787.490234375)
# ('epoch: %s %s  loss: %s', 12, 'TRAIN', -12344.5849609375)
# ('epoch: %s %s  loss: %s', 13, 'TRAIN', -13518.6953125)
# ('epoch: %s %s  loss: %s', 14, 'TRAIN', -13536.4228515625)
# ('epoch: %s %s  loss: %s', 15, 'TRAIN', -12531.265625)
# ('epoch: %s %s  loss: %s', 16, 'TRAIN', -13224.0185546875)
# ('epoch: %s %s  loss: %s', 17, 'TRAIN', -12951.455078125)
# ('epoch: %s %s  loss: %s', 18, 'TRAIN', -12195.2568359375)
# ('epoch: %s %s  loss: %s', 19, 'TRAIN', -11663.3427734375)
# ('epoch: %s %s  loss: %s', 20, 'TRAIN', -13499.150390625)
# ('epoch: %s %s  loss: %s', 21, 'TRAIN', -12052.5419921875)
# ('epoch: %s %s  loss: %s', 22, 'TRAIN', -12596.7890625)
# ('epoch: %s %s  loss: %s', 23, 'TRAIN', -12388.8779296875)
# ('epoch: %s %s  loss: %s', 24, 'TRAIN', -13231.7158203125)
# ('epoch: %s %s  loss: %s', 25, 'TRAIN', -12388.9951171875)
# ('epoch: %s %s  loss: %s', 26, 'TRAIN', -11583.9892578125)
# ('epoch: %s %s  loss: %s', 27, 'TRAIN', -13370.9267578125)
# ('epoch: %s %s  loss: %s', 28, 'TRAIN', -12875.1103515625)
# ('epoch: %s %s  loss: %s', 29, 'TRAIN', -12995.1748046875)

# %%
import matplotlib.pyplot as plt

# Combine the lists
labels = ["σ = 1", "σ = 0.5", "σ = 0.2"]#, "10", "15", "20"]
colors = ["blue", "orange", "green"]#, "red", "purple", "yellow"]

# Plot the data
xax = range(1,301,1)
for i, (acc, label, color) in enumerate(zip(val_lists1, labels, colors)):
    plt.plot(xax,acc, label=label, color=color)

# Add a horizontal line at y = -1
plt.axhline(y=-0, color="black", linestyle="--")

# Add labels and legend
plt.yscale('log')
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Breast cancer validation loss")
plt.legend()

SNOOP = [1, 3, 6, 30, 60]
for idx in SNOOP:
    for i in (acc_lists1):
        k = i
        k = sorted(k)
        print(sum(k[:idx])/idx)
# Out:
# 0.028908027336001396
# 0.08991163969039917
# 0.008468189276754856
# 0.03270363807678223
# 0.100403626759847
# 0.010502716526389122
# 0.037483961010972656
# 0.13161824891964594
# 0.012082301390667757
# 0.08189446826775869
# 0.19252646068731943
# 0.02665517311543226
# 0.11441903623441856
# 0.2267576900621255
# 0.0377355118903021

# %%
import matplotlib.pyplot as plt
import numpy as np
# Combine the lists
labels = ["1", "0.5", "0.2"]#, "10", "15", "20"]
colors = ["blue", "orange", "green"]#, "red", "purple", "yellow"]
d_list = [np.array(out_dicts1[0][-1]["elbo"])+100000, np.array(out_dicts1[1][-1]["elbo"])+100000, np.array(out_dicts1[2][-1]["elbo"])+100000]
# Plot the data
for i, (acc, label, color) in enumerate(zip(d_list, labels, colors)):
    plt.plot(acc, label=label, color=color)

# Add a horizontal line at y = -1
plt.axhline(y=-0, color="black", linestyle="--")

# Add labels and legend
plt.yscale('log')
plt.xlabel("Iteration")
plt.ylabel("Loss (symlog)")
plt.title("Breast cancer ELBO loss")
plt.legend()

# %%
import matplotlib.pyplot as plt

# Combine the lists
labels = ["4", "6", "8", "10", "15", "20"]
colors = ["blue", "orange", "green", "red", "purple", "yellow"]

# Plot the data
for i, (acc, label, color) in enumerate(zip(acc_lists1, labels, colors)):
    plt.plot(acc, label=label, color=color)

# Add a horizontal line at y = -1
plt.axhline(y=-0, color="black", linestyle="--")

# Add labels and legend
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss for different dimensions, σ = 100")
plt.legend()

# Show the plot
plt.show()

# %%
div = 1000
funnel_config.trainer.epochs = 300
acc_lists2 = []
out_dicts2 = []
for div in [1, 0.5, 0.2]:
    funnel_config = set_task(funnel_config, task, div, c)
    funnel_config.model.input_dim = 9
    out_dict = train_dds(funnel_config)
    out_dicts2.append(out_dict)
    acc_lists2.append([x.item() for x in out_dict[-1]["training_loss"]])

# %%
import matplotlib.pyplot as plt

# Combine the lists
labels = ["4", "6", "8", "10", "15", "20"]
colors = ["blue", "orange", "green", "red", "purple", "yellow"]

# Plot the data
for i, (acc, label, color) in enumerate(zip(acc_lists2, labels, colors)):
    plt.plot(acc, label=label, color=color)

# Add a horizontal line at y = -1
plt.axhline(y=-0, color="black", linestyle="--")

# Add labels and legend
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss for different dimensions, σ = 1000")
plt.legend()

# Show the plot
plt.show()

# %%
from utility_func import *
import visualisation
plot_training_loss(out_dict[-1]["elbo"])
print(out_dict[-1]["elbo"][-1])
visualisation.heat_2d(out_dict)

# %%
out_dict[-1].keys()

# %%
onp.mean(out_dict[-1]["is_eval"])

# %%
onp.mean(out_dict[-1]["pf_eval"])

# %%
out_dict[-1]["pf_eval"]

# %%
import matplotlib.pyplot as plt
import numpy as np

loss_list1, loss_list2, loss_list3 = [], [], []

for i in acc_lists:
    #loss_list1.append(np.log(min(i)))
    loss_list1.append(min(i))

for i in acc_lists1:
    #loss_list2.append(np.log(min(i)))
    loss_list2.append(min(i))

for i in acc_lists2:
    #loss_list3.append(np.log(min(i)))
    loss_list3.append(min(i))

# Combine the lists
loss_lists = [loss_list1, loss_list2, loss_list3]
labels = ['σ = 10', 'σ = 100', 'σ = 1000']
colors = ['blue', 'orange', 'green']

# Custom x-axis labels
x_labels = ["4", "6", "8", "10", "15", "20"]

# Plot the data
for i, (loss, label, color) in enumerate(zip(loss_lists, labels, colors)):
    plt.plot(x_labels, loss, label=label, color=color, marker="o")

# Add labels and legend
plt.yscale('log')
plt.xlabel("X-axis Label")
plt.ylabel("Loss")
plt.title("Loss vs. X-axis Label")
plt.legend()

# Show the plot
plt.show()

# %%
funnel_config.model.reference_process_key

# %%
print(out_dict[-1]["aug"].shape)

# %%
import matplotlib.pyplot as plt

#ode_targ = out_dict[-1]["aug_ode"][:, -1,:2]
sde_targ = out_dict[-1]["aug"][:, -1,:2]

#plt.plot(ode_targ[:, 0], abs(ode_targ[:, 1]), ".", alpha=0.4)
plt.plot(sde_targ[:, 0])#, sde_targ[:, 1], ".", alpha=0.4)
#print(onp.mean(sde_targ[:, 0]))

# %%
import numpy as np
data_x = []
data_fx = []
for sample in out_dict[-1]["aug"]:
    x = sample[-1][:input_dim-1]
    fx = abs(sample[-1][input_dim-1])
    data_x.append(x)
    data_fx.append(fx)

m = np.argmax(data_fx)
print(f"weights: {data_x[m]}")


# Create a list of tuples containing x, y, and z values
combined_data = zip(data_x, data_fx)

# Sort the combined data based on the z values in descending order
sorted_data = sorted(combined_data, key=lambda t: t[1], reverse=True)

# Unzip the sorted data back into separate x, y, and z lists
data_x_sorted, data_fx_sorted = zip(*sorted_data)

best = np.array(list(zip(data_x_sorted, data_fx_sorted)))[:100]
# avg = np.mean(best, axis=0)
# v, w = avg
# print(np.sin(3*np.pi*v) + (v - 1)**2 * (1+np.sin(3*np.pi*w)**2) + (w-1)**2 * (1 + np.sin(2*np.pi*w)**2))
# print(avg)
#print(best)
# for v,w in best:
#     v = np.sin(3*np.pi*v) + (v - 1)**2 * (1+np.sin(3*np.pi*w)**2) + (w-1)**2 * (1 + np.sin(2*np.pi*w)**2)
#     print(v)
from experimental.xor_t import xor_task
task = xor_task()
b = 1
w = None
print(len(data_x))
for weights in data_x:
#for weights, _ in best:
    l = task.get_loss(weights)
    #print(l)
    if l < b:
        b = l
        w = weights

print(b, w)

# %%
from visualisation import *

heat_2d(out_dict, save_name=save_name, sde=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = []
for sample in out_dict[-1]["aug"]:
    s = sample[-1]
    data.append(s)

# Compute the histogram values
hist, bin_edges = np.histogram(data, bins=100)

# Compute the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Create a line plot using Seaborn
sns.lineplot(x=bin_centers, y=hist)

# Set the x and y axis labels
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.axvline(x=0, color='red', linestyle='--', label='x=0.3', alpha=0.5)

# Show the plot
plt.show()

# %%
from dds.targets.toy_targets import *

car = carillo_target_class()
x_values = np.linspace(-10, 10, 1000)

# Compute the corresponding y values
# using the provided function
y_values = np.exp(-car.f(x_values) / 10)

#y_values = -norm.logpdf(y_values,loc=0., scale=1.)

# Create the plot
plt.plot(x_values, y_values)
plt.xlabel("v")
plt.ylabel("f(v)")
plt.title("Plot of the function f(v)")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from dds.targets.toy_targets import *


def temp(x):
    tc = levy_target_class(0,0)
    k = np.exp(-tc.f(x)/10) * 1000
    return k

def rosenbrock_function(x):
    return np.exp(-((1 - x[0])**2 + 100 * (x[1] - x[0]**2)**2)/0.01)

def rastrigin_function(x, A=10):
    n = len(x)
    return np.exp(-(A * n + np.sum(x**2 - A * np.cos(2 * np.pi * x)))/1)

# Create a grid of points for the plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the Rosenbrock function for each point in the grid
Z = np.array([temp(np.array([x, y])) for x, y in zip(np.ravel(X), np.ravel(Y))])
Z = Z.reshape(X.shape)

# Create a contour plot
plt.figure()
plt.contourf(X, Y, Z, levels=100, cmap='jet')
plt.colorbar()
plt.title('Rosenbrock Function')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %%
import numpy as np
import jax.numpy as jnp
from jax.scipy.special import logsumexp
import matplotlib.pyplot as plt

def euclidean_distance_einsum(x, y):
    """Efficiently calculates the euclidean distance between vectors in two mats.


    Args:
      x: first matrix (nxd)
      y: second matrix (mxd)

    Returns:
      pairwise distance matrix (nxm)
    """
    xx = jnp.einsum('ij,ij->i', x, x)[:, jnp.newaxis]
    yy = jnp.einsum('ij,ij->i', y, y)
    xy = 2 * jnp.dot(x, y.T)
    out = xx + yy - xy

    return out

def log_p_pure(x):
    """Gaussian mixture density on well like structure.

    Args:
      x: vectors over which to evaluate the density

    Returns:
      nx1 vector containing density evaluations
    """

    mu = 1.0
    sigma2_ = 0.05
    mus_full = np.array([
        [- mu, 0.0],
        [- mu, mu],
        [- mu, -mu],
        [- mu, 2 * mu],
        [- mu, - 2 * mu],
        [mu, 0.0],
        [mu, mu],
        [mu, -mu],
        [mu, 2 * mu],
        [mu, - 2 * mu],
    ])
    dist_to_means = euclidean_distance_einsum(x, mus_full)

    out = logsumexp(-dist_to_means / (0.01 * sigma2_), axis=1)

    return out

#print(log_p_pure(jnp.array([1,2]).reshape(1,2)))

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the Rosenbrock function for each point in the grid
Z = np.array([log_p_pure(np.array([x, y]).reshape(1,2)) for x, y in zip(np.ravel(X), np.ravel(Y))])
Z = Z.reshape(X.shape)

# Create a contour plot
plt.figure()
plt.contourf(X, Y, Z, levels=100, cmap='jet')
plt.colorbar()
plt.title('Rosenbrock Function')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()
